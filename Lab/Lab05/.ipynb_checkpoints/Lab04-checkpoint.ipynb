# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

def loadDataSet(fileName):
# Load subset of the training data
data = pd.read_csv('/Users/dengyangjie/Desktop/ML/Lab/Lab05/train1.csv',header=None)
features , labels = data.iloc[:,:-1] , data.iloc[:,-1]
print(features.shape)
print(labels.shape)
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.33, random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
# Out:
# (700, 2500)
# (700,)
# (469, 2500)
# (231, 2500)
# (469,)

# %%
import numpy as np
import pandas as pd

class SMO:
    def __init__(self, dataMatIn, classLabels, C, toler, Kernel='linear', sigma=0.):
        '''
        :param dataMatIn:
        :param classLabels:
        :param C: controls the relative weighting between the twin goals of making cost small
        and of ensuring that most examples have functional margin at least 1
        :param toler:  the convergence  tolerance parameter
        :param Kernel: I will update the function later
        '''
        self.X = np.array(dataMatIn)
        self.y = np.array(classLabels).T[:, np.newaxis]
        self.C = C
        self.tol = toler
        self.m = np.shape(dataMatIn)[0]
        self.alphas = np.zeros((self.m, 1))
        self.b = 0.
        self.eCache = np.zeros((self.m, 1))
        self.K = np.zeros((self.m, self.m))
        for i in range(self.m):
            self.K[:, i] = self.kernel(self.X, self.X[i, :], Kernel, sigma)

    def kernel(self, X, Z, Kernel, sigma):
        m, n = np.shape(X)
        k = np.zeros((m, 1))
        if Kernel == 'linear':
            k = np.dot(X, Z.T)
        elif Kernel == 'rbf':
            delta = X - Z
            k = np.exp(-np.sum(delta**2, axis=1) / (sigma ** 2))
        else:
            raise NameError("we don't have this kernel\n")
        return k

    def clipAlpha(self, aj, H, L):
        '''
        :param aj:
        :param H:
        :param L:
        :return: new aj between H and L
        '''
        if aj > H:
            aj = H
        if L > aj:
            aj = L
        return aj

    def calcE(self, i):
        '''
        :param i:
        :return:  a corresponding E value of ith data
        '''
        gxi = np.dot((self.alphas * self.y).T, self.K[:, i]) + self.b
        Ei = gxi - self.y[i]
        return Ei

    def selectJ(self, i, Ei):
        '''
        choose a second E value by compare others
        :param i:
        :param Ei:
        :return: best second E value
        '''
        maxK = -1
        maxDelta = 0
        Ej = 0
        self.eCache[i] = Ei
        for k in range(self.m):
            if k == i:
                continue
            Ek = self.calcE(k)
            deltaE = abs(Ei - Ek)
            if (deltaE > maxDelta):
                maxK = k
                maxDelta = deltaE
                Ej = Ek
        return maxK, Ej

    def updataE(self, k):
        '''
        update new E value after change the alpha
        :param k:
        :return:
        '''
        Ek = self.calcE(k)
        self.eCache[k] = Ek

    def innerLoop(self, i):
        '''
        inner loop in data, we update alphas value each iter
        :param i:
        :return:
        '''
        Ei = self.calcE(i)
        if ((self.y[i] * Ei < -self.tol) and (self.alphas[i] < self.C)) or \
                ((self.y[i] * Ei > self.tol) and (self.alphas[i] > self.C)):
            j, Ej = self.selectJ(i, Ei)
            alphaIold = self.alphas[i].copy()
            alphaJold = self.alphas[j].copy()
            if (self.y[i] != self.y[j]):
                L = max(0, alphaJold - alphaIold)
                H = min(self.C, self.C + alphaJold - alphaIold)
            else:
                L = max(0, alphaJold + alphaIold - self.C)
                H = min(self.C, alphaJold + alphaIold)
            if (L == H):
                print("L == H")
                return 0
            eta = self.K[i, i] + self.K[j, j] - 2 * self.K[i, j]

            if eta <= 0:
                print("eta <= 0")
                return 0
            alphaJnewUnc = alphaJold + self.y[j] * (Ei - Ej) / eta
            alphaJnew = self.clipAlpha(alphaJnewUnc, H, L)
            self.alphas[j] = alphaJnew
            self.updataE(j)
            if (abs(alphaJnew - alphaJold) < 0.0001):
                print("j not moving enough")
                return 0
            alphaInew = alphaIold + self.y[i] * self.y[j] * (alphaJold - alphaJnew)
            self.alphas[i] = alphaInew
            self.updataE(i)
            bi = self.b - Ei - self.y[i] * self.K[i, i] * (alphaInew - alphaIold) - \
                 self.y[j] * self.K[i, j]* (alphaJnew - alphaJold)
            bj = self.b - Ej - self.y[i] * self.K[i, j] * (alphaInew - alphaIold) - \
                 self.y[j] * self.K[j, j] * (alphaJnew - alphaJold)
            if (0 < alphaInew) and (alphaInew < self.C):
                self.b = bi
            elif (0 < alphaJnew) and (alphaJnew < self.C):
                self.b = bj
            else:
                self.b = (bi + bj) / 2.0
            return 1
        else:
            return 0

    def train(self, maxIter):
        '''
        train function
        :param maxIter:
        :return: b and alphas
        '''
        iter = 0
        entireSet = True
        alphaPairsChanged = 0
        for i in range(self.m):
            Ei = self.calcE(i)
            self.eCache[i] = Ei
        while (iter < maxIter) and ((alphaPairsChanged > 0) or (entireSet)):
            alphaPairsChanged = 0
            for i in range(self.m):
                alphaPairsChanged += self.innerLoop(i)
                print("fullSet, iter: %d i:%d, pairs changed %d" % (iter, i, alphaPairsChanged))
            iter += 1
        return self.b, self.alphas

    def calcLinearWs(self):
        w = np.sum(self.alphas * self.y * self.X, axis=0).transpose()
        # print(w.shape)
        return w
    

def predict(w,b,X):
    return np.sign(np.dot(X, w) + b)

def testLinear():
    data = pd.read_csv('/Users/dengyangjie/Desktop/ML/Lab/Lab05/train1.csv',header=None)
    dataArr, labelArr = np.array(data.iloc[:,:-1]) , np.array(data.iloc[:,-1])
    smo = SMO(dataArr, labelArr, 0.00001, 0.01, 'linear')
    b, alphas = smo.train(3)
    w = smo.calcLinearWs()
    
    data2 = pd.read_csv('/Users/dengyangjie/Desktop/ML/Lab/Lab05/test1.csv',header=None)
    features2 , labels2 = data2.iloc[:,:-1] , data2.iloc[:,-1]
    X_test = np.array(features2)
    y_test = np.array(labels2)
    y_predict = predict(w,b,X_test)
    correct = np.sum(y_predict == y_test)
    print("ACCURACY:%f" % (correct/len(y_predict)))

def testRBF():
    data = pd.read_csv('/Users/dengyangjie/Desktop/ML/Lab/Lab05/train2.csv',header=None)
    dataArr, labelArr = np.array(data.iloc[:,:-1]) , np.array(data.iloc[:,-1])
    smo = SMO(dataArr, labelArr, 2, 0.9, 'rbf', 2.1)
    b, alphas = smo.train(2)
    X = np.array(dataArr)
    y = np.array(labelArr).T[:, np.newaxis]
    svInd = np.nonzero(alphas > 0)[0]
    sVs = X[svInd]
    labelSV = y[svInd]
    print("there are %d Support Vectors" % np.shape(sVs)[0])
    m, n = np.shape(X)
    errorCount = 0
    # print(labelSV.shape, alphas.shape, len(b))
    for i in range(m):
        kernelEval = smo.kernel(sVs, X[i, :], 'rbf', 1.3)
        # print(np.shape(labelSV.T))
        predict = np.dot(kernelEval, labelSV * alphas[svInd]) + b
        if np.sign(predict) != np.sign(y[i]):
            errorCount += 1
    print("the training error rate is: %f" %(np.float(errorCount)/ m))
    data = pd.read_csv('/Users/dengyangjie/Desktop/ML/Lab/Lab05/test2.csv',header=None)
    X, y = np.array(data.iloc[:,:-1]) , np.array(data.iloc[:,-1]).T
    errorCount = 0
    m, n = np.shape(X)
    for i in range(m):
        kernelEval = smo.kernel(sVs, X[i, :], 'rbf', 1.3)
        predict = np.dot(kernelEval.T, labelSV * alphas[svInd]) + b
        if np.sign(predict) != np.sign(y[i]):
            errorCount += 1
    print("the test error rate is: %f" % (np.float(errorCount) / m))
    

testLinear()
# Out:
# j not moving enough
# fullSet, iter: 0 i:0, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:1, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:2, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:3, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:4, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:5, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:6, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:7, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:8, pairs changed 0
# L == H
# fullSet, iter: 0 i:9, pairs changed 0
# L == H
# fullSet, iter: 0 i:10, pairs changed 0
# L == H
# fullSet, iter: 0 i:11, pairs changed 0
# L == H
# fullSet, iter: 0 i:12, pairs changed 0
# L == H
# fullSet, iter: 0 i:13, pairs changed 0
# L == H
# fullSet, iter: 0 i:14, pairs changed 0
# L == H
# fullSet, iter: 0 i:15, pairs changed 0
# L == H
# fullSet, iter: 0 i:16, pairs changed 0
# L == H
# fullSet, iter: 0 i:17, pairs changed 0
# L == H
# fullSet, iter: 0 i:18, pairs changed 0
# L == H
# fullSet, iter: 0 i:19, pairs changed 0
# L == H
# fullSet, iter: 0 i:20, pairs changed 0
# L == H
# fullSet, iter: 0 i:21, pairs changed 0
# L == H
# fullSet, iter: 0 i:22, pairs changed 0
# L == H
# fullSet, iter: 0 i:23, pairs changed 0
# L == H
# fullSet, iter: 0 i:24, pairs changed 0
# L == H
# fullSet, iter: 0 i:25, pairs changed 0
# L == H
# fullSet, iter: 0 i:26, pairs changed 0
# L == H
# fullSet, iter: 0 i:27, pairs changed 0
# L == H
# fullSet, iter: 0 i:28, pairs changed 0
# L == H
# fullSet, iter: 0 i:29, pairs changed 0
# L == H
# fullSet, iter: 0 i:30, pairs changed 0
# L == H
# fullSet, iter: 0 i:31, pairs changed 0
# L == H
# fullSet, iter: 0 i:32, pairs changed 0
# L == H
# fullSet, iter: 0 i:33, pairs changed 0
# L == H
# fullSet, iter: 0 i:34, pairs changed 0
# L == H
# fullSet, iter: 0 i:35, pairs changed 0
# L == H
# fullSet, iter: 0 i:36, pairs changed 0
# L == H
# fullSet, iter: 0 i:37, pairs changed 0
# L == H
# fullSet, iter: 0 i:38, pairs changed 0
# L == H
# fullSet, iter: 0 i:39, pairs changed 0
# L == H
# fullSet, iter: 0 i:40, pairs changed 0
# L == H
# fullSet, iter: 0 i:41, pairs changed 0
# L == H
# fullSet, iter: 0 i:42, pairs changed 0
# L == H
# fullSet, iter: 0 i:43, pairs changed 0
# L == H
# fullSet, iter: 0 i:44, pairs changed 0
# L == H
# fullSet, iter: 0 i:45, pairs changed 0
# L == H
# fullSet, iter: 0 i:46, pairs changed 0
# L == H
# fullSet, iter: 0 i:47, pairs changed 0
# L == H
# fullSet, iter: 0 i:48, pairs changed 0
# L == H
# fullSet, iter: 0 i:49, pairs changed 0
# L == H
# fullSet, iter: 0 i:50, pairs changed 0
# L == H
# fullSet, iter: 0 i:51, pairs changed 0
# L == H
# fullSet, iter: 0 i:52, pairs changed 0
# L == H
# fullSet, iter: 0 i:53, pairs changed 0
# L == H
# fullSet, iter: 0 i:54, pairs changed 0
# L == H
# fullSet, iter: 0 i:55, pairs changed 0
# L == H
# fullSet, iter: 0 i:56, pairs changed 0
# L == H
# fullSet, iter: 0 i:57, pairs changed 0
# L == H
# fullSet, iter: 0 i:58, pairs changed 0
# L == H
# fullSet, iter: 0 i:59, pairs changed 0
# L == H
# fullSet, iter: 0 i:60, pairs changed 0
# L == H
# fullSet, iter: 0 i:61, pairs changed 0
# L == H
# fullSet, iter: 0 i:62, pairs changed 0
# L == H
# fullSet, iter: 0 i:63, pairs changed 0
# L == H
# fullSet, iter: 0 i:64, pairs changed 0
# L == H
# fullSet, iter: 0 i:65, pairs changed 0
# L == H
# fullSet, iter: 0 i:66, pairs changed 0
# L == H
# fullSet, iter: 0 i:67, pairs changed 0
# L == H
# fullSet, iter: 0 i:68, pairs changed 0
# L == H
# fullSet, iter: 0 i:69, pairs changed 0
# L == H
# fullSet, iter: 0 i:70, pairs changed 0
# L == H
# fullSet, iter: 0 i:71, pairs changed 0
# L == H
# fullSet, iter: 0 i:72, pairs changed 0
# L == H
# fullSet, iter: 0 i:73, pairs changed 0
# L == H
# fullSet, iter: 0 i:74, pairs changed 0
# L == H
# fullSet, iter: 0 i:75, pairs changed 0
# L == H
# fullSet, iter: 0 i:76, pairs changed 0
# L == H
# fullSet, iter: 0 i:77, pairs changed 0
# L == H
# fullSet, iter: 0 i:78, pairs changed 0
# L == H
# fullSet, iter: 0 i:79, pairs changed 0
# L == H
# fullSet, iter: 0 i:80, pairs changed 0
# L == H
# fullSet, iter: 0 i:81, pairs changed 0
# L == H
# fullSet, iter: 0 i:82, pairs changed 0
# L == H
# fullSet, iter: 0 i:83, pairs changed 0
# L == H
# fullSet, iter: 0 i:84, pairs changed 0
# L == H
# fullSet, iter: 0 i:85, pairs changed 0
# L == H
# fullSet, iter: 0 i:86, pairs changed 0
# L == H
# fullSet, iter: 0 i:87, pairs changed 0
# L == H
# fullSet, iter: 0 i:88, pairs changed 0
# L == H
# fullSet, iter: 0 i:89, pairs changed 0
# L == H
# fullSet, iter: 0 i:90, pairs changed 0
# L == H
# fullSet, iter: 0 i:91, pairs changed 0
# L == H
# fullSet, iter: 0 i:92, pairs changed 0
# L == H
# fullSet, iter: 0 i:93, pairs changed 0
# L == H
# fullSet, iter: 0 i:94, pairs changed 0
# L == H
# fullSet, iter: 0 i:95, pairs changed 0
# L == H
# fullSet, iter: 0 i:96, pairs changed 0
# L == H
# fullSet, iter: 0 i:97, pairs changed 0
# L == H
# fullSet, iter: 0 i:98, pairs changed 0
# L == H
# fullSet, iter: 0 i:99, pairs changed 0
# L == H
# fullSet, iter: 0 i:100, pairs changed 0
# L == H
# fullSet, iter: 0 i:101, pairs changed 0
# L == H
# fullSet, iter: 0 i:102, pairs changed 0
# L == H
# fullSet, iter: 0 i:103, pairs changed 0
# L == H
# fullSet, iter: 0 i:104, pairs changed 0
# L == H
# fullSet, iter: 0 i:105, pairs changed 0
# L == H
# fullSet, iter: 0 i:106, pairs changed 0
# L == H
# fullSet, iter: 0 i:107, pairs changed 0
# L == H
# fullSet, iter: 0 i:108, pairs changed 0
# L == H
# fullSet, iter: 0 i:109, pairs changed 0
# L == H
# fullSet, iter: 0 i:110, pairs changed 0
# L == H
# fullSet, iter: 0 i:111, pairs changed 0
# L == H
# fullSet, iter: 0 i:112, pairs changed 0
# L == H
# fullSet, iter: 0 i:113, pairs changed 0
# L == H
# fullSet, iter: 0 i:114, pairs changed 0
# L == H
# fullSet, iter: 0 i:115, pairs changed 0
# L == H
# fullSet, iter: 0 i:116, pairs changed 0
# L == H
# fullSet, iter: 0 i:117, pairs changed 0
# L == H
# fullSet, iter: 0 i:118, pairs changed 0
# L == H
# fullSet, iter: 0 i:119, pairs changed 0
# L == H
# fullSet, iter: 0 i:120, pairs changed 0
# L == H
# fullSet, iter: 0 i:121, pairs changed 0
# L == H
# fullSet, iter: 0 i:122, pairs changed 0
# L == H
# fullSet, iter: 0 i:123, pairs changed 0
# L == H
# fullSet, iter: 0 i:124, pairs changed 0
# L == H
# fullSet, iter: 0 i:125, pairs changed 0
# L == H
# fullSet, iter: 0 i:126, pairs changed 0
# L == H
# fullSet, iter: 0 i:127, pairs changed 0
# L == H
# fullSet, iter: 0 i:128, pairs changed 0
# L == H
# fullSet, iter: 0 i:129, pairs changed 0
# L == H
# fullSet, iter: 0 i:130, pairs changed 0
# L == H
# fullSet, iter: 0 i:131, pairs changed 0
# L == H
# fullSet, iter: 0 i:132, pairs changed 0
# L == H
# fullSet, iter: 0 i:133, pairs changed 0
# L == H
# fullSet, iter: 0 i:134, pairs changed 0
# L == H
# fullSet, iter: 0 i:135, pairs changed 0
# L == H
# fullSet, iter: 0 i:136, pairs changed 0
# L == H
# fullSet, iter: 0 i:137, pairs changed 0
# L == H
# fullSet, iter: 0 i:138, pairs changed 0
# L == H
# fullSet, iter: 0 i:139, pairs changed 0
# L == H
# fullSet, iter: 0 i:140, pairs changed 0
# L == H
# fullSet, iter: 0 i:141, pairs changed 0
# L == H
# fullSet, iter: 0 i:142, pairs changed 0
# L == H
# fullSet, iter: 0 i:143, pairs changed 0
# L == H
# fullSet, iter: 0 i:144, pairs changed 0
# L == H
# fullSet, iter: 0 i:145, pairs changed 0
# L == H
# fullSet, iter: 0 i:146, pairs changed 0
# L == H
# fullSet, iter: 0 i:147, pairs changed 0
# L == H
# fullSet, iter: 0 i:148, pairs changed 0
# L == H
# fullSet, iter: 0 i:149, pairs changed 0
# L == H
# fullSet, iter: 0 i:150, pairs changed 0
# L == H
# fullSet, iter: 0 i:151, pairs changed 0
# L == H
# fullSet, iter: 0 i:152, pairs changed 0
# L == H
# fullSet, iter: 0 i:153, pairs changed 0
# L == H
# fullSet, iter: 0 i:154, pairs changed 0
# L == H
# fullSet, iter: 0 i:155, pairs changed 0
# L == H
# fullSet, iter: 0 i:156, pairs changed 0
# L == H
# fullSet, iter: 0 i:157, pairs changed 0
# L == H
# fullSet, iter: 0 i:158, pairs changed 0
# L == H
# fullSet, iter: 0 i:159, pairs changed 0
# L == H
# fullSet, iter: 0 i:160, pairs changed 0
# L == H
# fullSet, iter: 0 i:161, pairs changed 0
# L == H
# fullSet, iter: 0 i:162, pairs changed 0
# L == H
# fullSet, iter: 0 i:163, pairs changed 0
# L == H
# fullSet, iter: 0 i:164, pairs changed 0
# L == H
# fullSet, iter: 0 i:165, pairs changed 0
# L == H
# fullSet, iter: 0 i:166, pairs changed 0
# L == H
# fullSet, iter: 0 i:167, pairs changed 0
# L == H
# fullSet, iter: 0 i:168, pairs changed 0
# L == H
# fullSet, iter: 0 i:169, pairs changed 0
# L == H
# fullSet, iter: 0 i:170, pairs changed 0
# L == H
# fullSet, iter: 0 i:171, pairs changed 0
# L == H
# fullSet, iter: 0 i:172, pairs changed 0
# L == H
# fullSet, iter: 0 i:173, pairs changed 0
# L == H
# fullSet, iter: 0 i:174, pairs changed 0
# L == H
# fullSet, iter: 0 i:175, pairs changed 0
# L == H
# fullSet, iter: 0 i:176, pairs changed 0
# L == H
# fullSet, iter: 0 i:177, pairs changed 0
# L == H
# fullSet, iter: 0 i:178, pairs changed 0
# L == H
# fullSet, iter: 0 i:179, pairs changed 0
# L == H
# fullSet, iter: 0 i:180, pairs changed 0
# L == H
# fullSet, iter: 0 i:181, pairs changed 0
# L == H
# fullSet, iter: 0 i:182, pairs changed 0
# L == H
# fullSet, iter: 0 i:183, pairs changed 0
# L == H
# fullSet, iter: 0 i:184, pairs changed 0
# L == H
# fullSet, iter: 0 i:185, pairs changed 0
# L == H
# fullSet, iter: 0 i:186, pairs changed 0
# L == H
# fullSet, iter: 0 i:187, pairs changed 0
# L == H
# fullSet, iter: 0 i:188, pairs changed 0
# L == H
# fullSet, iter: 0 i:189, pairs changed 0
# L == H
# fullSet, iter: 0 i:190, pairs changed 0
# L == H
# fullSet, iter: 0 i:191, pairs changed 0
# L == H
# fullSet, iter: 0 i:192, pairs changed 0
# L == H
# fullSet, iter: 0 i:193, pairs changed 0
# L == H
# fullSet, iter: 0 i:194, pairs changed 0
# L == H
# fullSet, iter: 0 i:195, pairs changed 0
# L == H
# fullSet, iter: 0 i:196, pairs changed 0
# L == H
# fullSet, iter: 0 i:197, pairs changed 0
# L == H
# fullSet, iter: 0 i:198, pairs changed 0
# L == H
# fullSet, iter: 0 i:199, pairs changed 0
# L == H
# fullSet, iter: 0 i:200, pairs changed 0
# L == H
# fullSet, iter: 0 i:201, pairs changed 0
# L == H
# fullSet, iter: 0 i:202, pairs changed 0
# L == H
# fullSet, iter: 0 i:203, pairs changed 0
# L == H
# fullSet, iter: 0 i:204, pairs changed 0
# L == H
# fullSet, iter: 0 i:205, pairs changed 0
# L == H
# fullSet, iter: 0 i:206, pairs changed 0
# L == H
# fullSet, iter: 0 i:207, pairs changed 0
# L == H
# fullSet, iter: 0 i:208, pairs changed 0
# L == H
# fullSet, iter: 0 i:209, pairs changed 0
# L == H
# fullSet, iter: 0 i:210, pairs changed 0
# L == H
# fullSet, iter: 0 i:211, pairs changed 0
# L == H
# fullSet, iter: 0 i:212, pairs changed 0
# L == H
# fullSet, iter: 0 i:213, pairs changed 0
# L == H
# fullSet, iter: 0 i:214, pairs changed 0
# L == H
# fullSet, iter: 0 i:215, pairs changed 0
# L == H
# fullSet, iter: 0 i:216, pairs changed 0
# L == H
# fullSet, iter: 0 i:217, pairs changed 0
# L == H
# fullSet, iter: 0 i:218, pairs changed 0
# L == H
# fullSet, iter: 0 i:219, pairs changed 0
# L == H
# fullSet, iter: 0 i:220, pairs changed 0
# L == H
# fullSet, iter: 0 i:221, pairs changed 0
# L == H
# fullSet, iter: 0 i:222, pairs changed 0
# L == H
# fullSet, iter: 0 i:223, pairs changed 0
# L == H
# fullSet, iter: 0 i:224, pairs changed 0
# L == H
# fullSet, iter: 0 i:225, pairs changed 0
# L == H
# fullSet, iter: 0 i:226, pairs changed 0
# L == H
# fullSet, iter: 0 i:227, pairs changed 0
# L == H
# fullSet, iter: 0 i:228, pairs changed 0
# L == H
# fullSet, iter: 0 i:229, pairs changed 0
# L == H
# fullSet, iter: 0 i:230, pairs changed 0
# L == H
# fullSet, iter: 0 i:231, pairs changed 0
# L == H
# fullSet, iter: 0 i:232, pairs changed 0
# L == H
# fullSet, iter: 0 i:233, pairs changed 0
# L == H
# fullSet, iter: 0 i:234, pairs changed 0
# L == H
# fullSet, iter: 0 i:235, pairs changed 0
# L == H
# fullSet, iter: 0 i:236, pairs changed 0
# L == H
# fullSet, iter: 0 i:237, pairs changed 0
# L == H
# fullSet, iter: 0 i:238, pairs changed 0
# L == H
# fullSet, iter: 0 i:239, pairs changed 0
# L == H
# fullSet, iter: 0 i:240, pairs changed 0
# L == H
# fullSet, iter: 0 i:241, pairs changed 0
# L == H
# fullSet, iter: 0 i:242, pairs changed 0
# L == H
# fullSet, iter: 0 i:243, pairs changed 0
# L == H
# fullSet, iter: 0 i:244, pairs changed 0
# L == H
# fullSet, iter: 0 i:245, pairs changed 0
# L == H
# fullSet, iter: 0 i:246, pairs changed 0
# L == H
# fullSet, iter: 0 i:247, pairs changed 0
# L == H
# fullSet, iter: 0 i:248, pairs changed 0
# L == H
# fullSet, iter: 0 i:249, pairs changed 0
# L == H
# fullSet, iter: 0 i:250, pairs changed 0
# L == H
# fullSet, iter: 0 i:251, pairs changed 0
# L == H
# fullSet, iter: 0 i:252, pairs changed 0
# L == H
# fullSet, iter: 0 i:253, pairs changed 0
# L == H
# fullSet, iter: 0 i:254, pairs changed 0
# L == H
# fullSet, iter: 0 i:255, pairs changed 0
# L == H
# fullSet, iter: 0 i:256, pairs changed 0
# L == H
# fullSet, iter: 0 i:257, pairs changed 0
# L == H
# fullSet, iter: 0 i:258, pairs changed 0
# L == H
# fullSet, iter: 0 i:259, pairs changed 0
# L == H
# fullSet, iter: 0 i:260, pairs changed 0
# L == H
# fullSet, iter: 0 i:261, pairs changed 0
# L == H
# fullSet, iter: 0 i:262, pairs changed 0
# L == H
# fullSet, iter: 0 i:263, pairs changed 0
# L == H
# fullSet, iter: 0 i:264, pairs changed 0
# L == H
# fullSet, iter: 0 i:265, pairs changed 0
# L == H
# fullSet, iter: 0 i:266, pairs changed 0
# L == H
# fullSet, iter: 0 i:267, pairs changed 0
# L == H
# fullSet, iter: 0 i:268, pairs changed 0
# L == H
# fullSet, iter: 0 i:269, pairs changed 0
# L == H
# fullSet, iter: 0 i:270, pairs changed 0
# L == H
# fullSet, iter: 0 i:271, pairs changed 0
# L == H
# fullSet, iter: 0 i:272, pairs changed 0
# L == H
# fullSet, iter: 0 i:273, pairs changed 0
# L == H
# fullSet, iter: 0 i:274, pairs changed 0
# L == H
# fullSet, iter: 0 i:275, pairs changed 0
# L == H
# fullSet, iter: 0 i:276, pairs changed 0
# L == H
# fullSet, iter: 0 i:277, pairs changed 0
# L == H
# fullSet, iter: 0 i:278, pairs changed 0
# L == H
# fullSet, iter: 0 i:279, pairs changed 0
# L == H
# fullSet, iter: 0 i:280, pairs changed 0
# L == H
# fullSet, iter: 0 i:281, pairs changed 0
# L == H
# fullSet, iter: 0 i:282, pairs changed 0
# L == H
# fullSet, iter: 0 i:283, pairs changed 0
# L == H
# fullSet, iter: 0 i:284, pairs changed 0
# L == H
# fullSet, iter: 0 i:285, pairs changed 0
# L == H
# fullSet, iter: 0 i:286, pairs changed 0
# L == H
# fullSet, iter: 0 i:287, pairs changed 0
# L == H
# fullSet, iter: 0 i:288, pairs changed 0
# L == H
# fullSet, iter: 0 i:289, pairs changed 0
# L == H
# fullSet, iter: 0 i:290, pairs changed 0
# L == H
# fullSet, iter: 0 i:291, pairs changed 0
# L == H
# fullSet, iter: 0 i:292, pairs changed 0
# L == H
# fullSet, iter: 0 i:293, pairs changed 0
# L == H
# fullSet, iter: 0 i:294, pairs changed 0
# L == H
# fullSet, iter: 0 i:295, pairs changed 0
# L == H
# fullSet, iter: 0 i:296, pairs changed 0
# L == H
# fullSet, iter: 0 i:297, pairs changed 0
# L == H
# fullSet, iter: 0 i:298, pairs changed 0
# L == H
# fullSet, iter: 0 i:299, pairs changed 0
# L == H
# fullSet, iter: 0 i:300, pairs changed 0
# L == H
# fullSet, iter: 0 i:301, pairs changed 0
# L == H
# fullSet, iter: 0 i:302, pairs changed 0
# L == H
# fullSet, iter: 0 i:303, pairs changed 0
# L == H
# fullSet, iter: 0 i:304, pairs changed 0
# L == H
# fullSet, iter: 0 i:305, pairs changed 0
# L == H
# fullSet, iter: 0 i:306, pairs changed 0
# L == H
# fullSet, iter: 0 i:307, pairs changed 0
# L == H
# fullSet, iter: 0 i:308, pairs changed 0
# L == H
# fullSet, iter: 0 i:309, pairs changed 0
# L == H
# fullSet, iter: 0 i:310, pairs changed 0
# L == H
# fullSet, iter: 0 i:311, pairs changed 0
# L == H
# fullSet, iter: 0 i:312, pairs changed 0
# L == H
# fullSet, iter: 0 i:313, pairs changed 0
# L == H
# fullSet, iter: 0 i:314, pairs changed 0
# L == H
# fullSet, iter: 0 i:315, pairs changed 0
# L == H
# fullSet, iter: 0 i:316, pairs changed 0
# L == H
# fullSet, iter: 0 i:317, pairs changed 0
# L == H
# fullSet, iter: 0 i:318, pairs changed 0
# L == H
# fullSet, iter: 0 i:319, pairs changed 0
# L == H
# fullSet, iter: 0 i:320, pairs changed 0
# L == H
# fullSet, iter: 0 i:321, pairs changed 0
# L == H
# fullSet, iter: 0 i:322, pairs changed 0
# L == H
# fullSet, iter: 0 i:323, pairs changed 0
# L == H
# fullSet, iter: 0 i:324, pairs changed 0
# L == H
# fullSet, iter: 0 i:325, pairs changed 0
# L == H
# fullSet, iter: 0 i:326, pairs changed 0
# L == H
# fullSet, iter: 0 i:327, pairs changed 0
# L == H
# fullSet, iter: 0 i:328, pairs changed 0
# L == H
# fullSet, iter: 0 i:329, pairs changed 0
# L == H
# fullSet, iter: 0 i:330, pairs changed 0
# L == H
# fullSet, iter: 0 i:331, pairs changed 0
# L == H
# fullSet, iter: 0 i:332, pairs changed 0
# L == H
# fullSet, iter: 0 i:333, pairs changed 0
# L == H
# fullSet, iter: 0 i:334, pairs changed 0
# L == H
# fullSet, iter: 0 i:335, pairs changed 0
# L == H
# fullSet, iter: 0 i:336, pairs changed 0
# L == H
# fullSet, iter: 0 i:337, pairs changed 0
# L == H
# fullSet, iter: 0 i:338, pairs changed 0
# L == H
# fullSet, iter: 0 i:339, pairs changed 0
# L == H
# fullSet, iter: 0 i:340, pairs changed 0
# L == H
# fullSet, iter: 0 i:341, pairs changed 0
# L == H
# fullSet, iter: 0 i:342, pairs changed 0
# L == H
# fullSet, iter: 0 i:343, pairs changed 0
# L == H
# fullSet, iter: 0 i:344, pairs changed 0
# L == H
# fullSet, iter: 0 i:345, pairs changed 0
# L == H
# fullSet, iter: 0 i:346, pairs changed 0
# L == H
# fullSet, iter: 0 i:347, pairs changed 0
# L == H
# fullSet, iter: 0 i:348, pairs changed 0
# L == H
# fullSet, iter: 0 i:349, pairs changed 0
# fullSet, iter: 0 i:350, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:351, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:352, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:353, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:354, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:355, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:356, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:357, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:358, pairs changed 0
# j not moving enough
# fullSet, iter: 0 i:359, pairs changed 0
# L == H
# fullSet, iter: 0 i:360, pairs changed 0
# L == H
# fullSet, iter: 0 i:361, pairs changed 0
# L == H
# fullSet, iter: 0 i:362, pairs changed 0
# L == H
# fullSet, iter: 0 i:363, pairs changed 0
# L == H
# fullSet, iter: 0 i:364, pairs changed 0
# L == H
# fullSet, iter: 0 i:365, pairs changed 0
# L == H
# fullSet, iter: 0 i:366, pairs changed 0
# L == H
# fullSet, iter: 0 i:367, pairs changed 0
# L == H
# fullSet, iter: 0 i:368, pairs changed 0
# L == H
# fullSet, iter: 0 i:369, pairs changed 0
# L == H
# fullSet, iter: 0 i:370, pairs changed 0
# L == H
# fullSet, iter: 0 i:371, pairs changed 0
# L == H
# fullSet, iter: 0 i:372, pairs changed 0
# L == H
# fullSet, iter: 0 i:373, pairs changed 0
# L == H
# fullSet, iter: 0 i:374, pairs changed 0
# L == H
# fullSet, iter: 0 i:375, pairs changed 0
# L == H
# fullSet, iter: 0 i:376, pairs changed 0
# L == H
# fullSet, iter: 0 i:377, pairs changed 0
# L == H
# fullSet, iter: 0 i:378, pairs changed 0
# L == H
# fullSet, iter: 0 i:379, pairs changed 0
# L == H
# fullSet, iter: 0 i:380, pairs changed 0
# L == H
# fullSet, iter: 0 i:381, pairs changed 0
# L == H
# fullSet, iter: 0 i:382, pairs changed 0
# L == H
# fullSet, iter: 0 i:383, pairs changed 0
# L == H
# fullSet, iter: 0 i:384, pairs changed 0
# L == H
# fullSet, iter: 0 i:385, pairs changed 0
# L == H
# fullSet, iter: 0 i:386, pairs changed 0
# L == H
# fullSet, iter: 0 i:387, pairs changed 0
# L == H
# fullSet, iter: 0 i:388, pairs changed 0
# L == H
# fullSet, iter: 0 i:389, pairs changed 0
# L == H
# fullSet, iter: 0 i:390, pairs changed 0
# L == H
# fullSet, iter: 0 i:391, pairs changed 0
# L == H
# fullSet, iter: 0 i:392, pairs changed 0
# L == H
# fullSet, iter: 0 i:393, pairs changed 0
# L == H
# fullSet, iter: 0 i:394, pairs changed 0
# L == H
# fullSet, iter: 0 i:395, pairs changed 0
# L == H
# fullSet, iter: 0 i:396, pairs changed 0
# L == H
# fullSet, iter: 0 i:397, pairs changed 0
# L == H
# fullSet, iter: 0 i:398, pairs changed 0
# L == H
# fullSet, iter: 0 i:399, pairs changed 0
# L == H
# fullSet, iter: 0 i:400, pairs changed 0
# L == H
# fullSet, iter: 0 i:401, pairs changed 0
# L == H
# fullSet, iter: 0 i:402, pairs changed 0
# L == H
# fullSet, iter: 0 i:403, pairs changed 0
# L == H
# fullSet, iter: 0 i:404, pairs changed 0
# L == H
# fullSet, iter: 0 i:405, pairs changed 0
# L == H
# fullSet, iter: 0 i:406, pairs changed 0
# L == H
# fullSet, iter: 0 i:407, pairs changed 0
# L == H
# fullSet, iter: 0 i:408, pairs changed 0
# L == H
# fullSet, iter: 0 i:409, pairs changed 0
# L == H
# fullSet, iter: 0 i:410, pairs changed 0
# L == H
# fullSet, iter: 0 i:411, pairs changed 0
# L == H
# fullSet, iter: 0 i:412, pairs changed 0
# L == H
# fullSet, iter: 0 i:413, pairs changed 0
# L == H
# fullSet, iter: 0 i:414, pairs changed 0
# L == H
# fullSet, iter: 0 i:415, pairs changed 0
# L == H
# fullSet, iter: 0 i:416, pairs changed 0
# L == H
# fullSet, iter: 0 i:417, pairs changed 0
# L == H
# fullSet, iter: 0 i:418, pairs changed 0
# L == H
# fullSet, iter: 0 i:419, pairs changed 0
# L == H
# fullSet, iter: 0 i:420, pairs changed 0
# L == H
# fullSet, iter: 0 i:421, pairs changed 0
# L == H
# fullSet, iter: 0 i:422, pairs changed 0
# L == H
# fullSet, iter: 0 i:423, pairs changed 0
# L == H
# fullSet, iter: 0 i:424, pairs changed 0
# L == H
# fullSet, iter: 0 i:425, pairs changed 0
# L == H
# fullSet, iter: 0 i:426, pairs changed 0
# L == H
# fullSet, iter: 0 i:427, pairs changed 0
# L == H
# fullSet, iter: 0 i:428, pairs changed 0
# L == H
# fullSet, iter: 0 i:429, pairs changed 0
# L == H
# fullSet, iter: 0 i:430, pairs changed 0
# L == H
# fullSet, iter: 0 i:431, pairs changed 0
# L == H
# fullSet, iter: 0 i:432, pairs changed 0
# L == H
# fullSet, iter: 0 i:433, pairs changed 0
# L == H
# fullSet, iter: 0 i:434, pairs changed 0
# L == H
# fullSet, iter: 0 i:435, pairs changed 0
# L == H
# fullSet, iter: 0 i:436, pairs changed 0
# L == H
# fullSet, iter: 0 i:437, pairs changed 0
# L == H
# fullSet, iter: 0 i:438, pairs changed 0
# L == H
# fullSet, iter: 0 i:439, pairs changed 0
# L == H
# fullSet, iter: 0 i:440, pairs changed 0
# L == H
# fullSet, iter: 0 i:441, pairs changed 0
# L == H
# fullSet, iter: 0 i:442, pairs changed 0
# L == H
# fullSet, iter: 0 i:443, pairs changed 0
# L == H
# fullSet, iter: 0 i:444, pairs changed 0
# L == H
# fullSet, iter: 0 i:445, pairs changed 0
# L == H
# fullSet, iter: 0 i:446, pairs changed 0
# L == H
# fullSet, iter: 0 i:447, pairs changed 0
# L == H
# fullSet, iter: 0 i:448, pairs changed 0
# L == H
# fullSet, iter: 0 i:449, pairs changed 0
# L == H
# fullSet, iter: 0 i:450, pairs changed 0
# L == H
# fullSet, iter: 0 i:451, pairs changed 0
# L == H
# fullSet, iter: 0 i:452, pairs changed 0
# L == H
# fullSet, iter: 0 i:453, pairs changed 0
# L == H
# fullSet, iter: 0 i:454, pairs changed 0
# L == H
# fullSet, iter: 0 i:455, pairs changed 0
# L == H
# fullSet, iter: 0 i:456, pairs changed 0
# fullSet, iter: 0 i:457, pairs changed 0
# L == H
# fullSet, iter: 0 i:458, pairs changed 0
# L == H
# fullSet, iter: 0 i:459, pairs changed 0
# L == H
# fullSet, iter: 0 i:460, pairs changed 0
# L == H
# fullSet, iter: 0 i:461, pairs changed 0
# L == H
# fullSet, iter: 0 i:462, pairs changed 0
# L == H
# fullSet, iter: 0 i:463, pairs changed 0
# L == H
# fullSet, iter: 0 i:464, pairs changed 0
# L == H
# fullSet, iter: 0 i:465, pairs changed 0
# L == H
# fullSet, iter: 0 i:466, pairs changed 0
# L == H
# fullSet, iter: 0 i:467, pairs changed 0
# L == H
# fullSet, iter: 0 i:468, pairs changed 0
# L == H
# fullSet, iter: 0 i:469, pairs changed 0
# L == H
# fullSet, iter: 0 i:470, pairs changed 0
# L == H
# fullSet, iter: 0 i:471, pairs changed 0
# L == H
# fullSet, iter: 0 i:472, pairs changed 0
# L == H
# fullSet, iter: 0 i:473, pairs changed 0
# L == H
# fullSet, iter: 0 i:474, pairs changed 0
# L == H
# fullSet, iter: 0 i:475, pairs changed 0
# L == H
# fullSet, iter: 0 i:476, pairs changed 0
# L == H
# fullSet, iter: 0 i:477, pairs changed 0
# L == H
# fullSet, iter: 0 i:478, pairs changed 0
# L == H
# fullSet, iter: 0 i:479, pairs changed 0
# fullSet, iter: 0 i:480, pairs changed 0
# L == H
# fullSet, iter: 0 i:481, pairs changed 0
# L == H
# fullSet, iter: 0 i:482, pairs changed 0
# L == H
# fullSet, iter: 0 i:483, pairs changed 0
# fullSet, iter: 0 i:484, pairs changed 0
# L == H
# fullSet, iter: 0 i:485, pairs changed 0
# L == H
# fullSet, iter: 0 i:486, pairs changed 0
# L == H
# fullSet, iter: 0 i:487, pairs changed 0
# L == H
# fullSet, iter: 0 i:488, pairs changed 0
# L == H
# fullSet, iter: 0 i:489, pairs changed 0
# L == H
# fullSet, iter: 0 i:490, pairs changed 0
# L == H
# fullSet, iter: 0 i:491, pairs changed 0
# L == H
# fullSet, iter: 0 i:492, pairs changed 0
# L == H
# fullSet, iter: 0 i:493, pairs changed 0
# L == H
# fullSet, iter: 0 i:494, pairs changed 0
# L == H
# fullSet, iter: 0 i:495, pairs changed 0
# L == H
# fullSet, iter: 0 i:496, pairs changed 0
# L == H
# fullSet, iter: 0 i:497, pairs changed 0
# L == H
# fullSet, iter: 0 i:498, pairs changed 0
# L == H
# fullSet, iter: 0 i:499, pairs changed 0
# L == H
# fullSet, iter: 0 i:500, pairs changed 0
# L == H
# fullSet, iter: 0 i:501, pairs changed 0
# L == H
# fullSet, iter: 0 i:502, pairs changed 0
# L == H
# fullSet, iter: 0 i:503, pairs changed 0
# fullSet, iter: 0 i:504, pairs changed 0
# L == H
# fullSet, iter: 0 i:505, pairs changed 0
# L == H
# fullSet, iter: 0 i:506, pairs changed 0
# L == H
# fullSet, iter: 0 i:507, pairs changed 0
# L == H
# fullSet, iter: 0 i:508, pairs changed 0
# L == H
# fullSet, iter: 0 i:509, pairs changed 0
# L == H
# fullSet, iter: 0 i:510, pairs changed 0
# L == H
# fullSet, iter: 0 i:511, pairs changed 0
# L == H
# fullSet, iter: 0 i:512, pairs changed 0
# L == H
# fullSet, iter: 0 i:513, pairs changed 0
# L == H
# fullSet, iter: 0 i:514, pairs changed 0
# L == H
# fullSet, iter: 0 i:515, pairs changed 0
# L == H
# fullSet, iter: 0 i:516, pairs changed 0
# L == H
# fullSet, iter: 0 i:517, pairs changed 0
# L == H
# fullSet, iter: 0 i:518, pairs changed 0
# L == H
# fullSet, iter: 0 i:519, pairs changed 0
# L == H
# fullSet, iter: 0 i:520, pairs changed 0
# L == H
# fullSet, iter: 0 i:521, pairs changed 0
# L == H
# fullSet, iter: 0 i:522, pairs changed 0
# fullSet, iter: 0 i:523, pairs changed 0
# L == H
# fullSet, iter: 0 i:524, pairs changed 0
# L == H
# fullSet, iter: 0 i:525, pairs changed 0
# L == H
# fullSet, iter: 0 i:526, pairs changed 0
# L == H
# fullSet, iter: 0 i:527, pairs changed 0
# L == H
# fullSet, iter: 0 i:528, pairs changed 0
# L == H
# fullSet, iter: 0 i:529, pairs changed 0
# L == H
# fullSet, iter: 0 i:530, pairs changed 0
# L == H
# fullSet, iter: 0 i:531, pairs changed 0
# L == H
# fullSet, iter: 0 i:532, pairs changed 0
# L == H
# fullSet, iter: 0 i:533, pairs changed 0
# L == H
# fullSet, iter: 0 i:534, pairs changed 0
# L == H
# fullSet, iter: 0 i:535, pairs changed 0
# L == H
# fullSet, iter: 0 i:536, pairs changed 0
# L == H
# fullSet, iter: 0 i:537, pairs changed 0
# L == H
# fullSet, iter: 0 i:538, pairs changed 0
# L == H
# fullSet, iter: 0 i:539, pairs changed 0
# L == H
# fullSet, iter: 0 i:540, pairs changed 0
# L == H
# fullSet, iter: 0 i:541, pairs changed 0
# L == H
# fullSet, iter: 0 i:542, pairs changed 0
# L == H
# fullSet, iter: 0 i:543, pairs changed 0
# L == H
# fullSet, iter: 0 i:544, pairs changed 0
# L == H
# fullSet, iter: 0 i:545, pairs changed 0
# L == H
# fullSet, iter: 0 i:546, pairs changed 0
# L == H
# fullSet, iter: 0 i:547, pairs changed 0
# L == H
# fullSet, iter: 0 i:548, pairs changed 0
# L == H
# fullSet, iter: 0 i:549, pairs changed 0
# L == H
# fullSet, iter: 0 i:550, pairs changed 0
# L == H
# fullSet, iter: 0 i:551, pairs changed 0
# L == H
# fullSet, iter: 0 i:552, pairs changed 0
# L == H
# fullSet, iter: 0 i:553, pairs changed 0
# L == H
# fullSet, iter: 0 i:554, pairs changed 0
# L == H
# fullSet, iter: 0 i:555, pairs changed 0
# L == H
# fullSet, iter: 0 i:556, pairs changed 0
# L == H
# fullSet, iter: 0 i:557, pairs changed 0
# L == H
# fullSet, iter: 0 i:558, pairs changed 0
# L == H
# fullSet, iter: 0 i:559, pairs changed 0
# L == H
# fullSet, iter: 0 i:560, pairs changed 0
# L == H
# fullSet, iter: 0 i:561, pairs changed 0
# L == H
# fullSet, iter: 0 i:562, pairs changed 0
# L == H
# fullSet, iter: 0 i:563, pairs changed 0
# L == H
# fullSet, iter: 0 i:564, pairs changed 0
# L == H
# fullSet, iter: 0 i:565, pairs changed 0
# L == H
# fullSet, iter: 0 i:566, pairs changed 0
# L == H
# fullSet, iter: 0 i:567, pairs changed 0
# L == H
# fullSet, iter: 0 i:568, pairs changed 0
# L == H
# fullSet, iter: 0 i:569, pairs changed 0
# L == H
# fullSet, iter: 0 i:570, pairs changed 0
# L == H
# fullSet, iter: 0 i:571, pairs changed 0
# L == H
# fullSet, iter: 0 i:572, pairs changed 0
# L == H
# fullSet, iter: 0 i:573, pairs changed 0
# L == H
# fullSet, iter: 0 i:574, pairs changed 0
# L == H
# fullSet, iter: 0 i:575, pairs changed 0
# L == H
# fullSet, iter: 0 i:576, pairs changed 0
# L == H
# fullSet, iter: 0 i:577, pairs changed 0
# L == H
# fullSet, iter: 0 i:578, pairs changed 0
# L == H
# fullSet, iter: 0 i:579, pairs changed 0
# L == H
# fullSet, iter: 0 i:580, pairs changed 0
# L == H
# fullSet, iter: 0 i:581, pairs changed 0
# L == H
# fullSet, iter: 0 i:582, pairs changed 0
# L == H
# fullSet, iter: 0 i:583, pairs changed 0
# L == H
# fullSet, iter: 0 i:584, pairs changed 0
# L == H
# fullSet, iter: 0 i:585, pairs changed 0
# L == H
# fullSet, iter: 0 i:586, pairs changed 0
# L == H
# fullSet, iter: 0 i:587, pairs changed 0
# L == H
# fullSet, iter: 0 i:588, pairs changed 0
# L == H
# fullSet, iter: 0 i:589, pairs changed 0
# L == H
# fullSet, iter: 0 i:590, pairs changed 0
# L == H
# fullSet, iter: 0 i:591, pairs changed 0
# L == H
# fullSet, iter: 0 i:592, pairs changed 0
# L == H
# fullSet, iter: 0 i:593, pairs changed 0
# L == H
# fullSet, iter: 0 i:594, pairs changed 0
# L == H
# fullSet, iter: 0 i:595, pairs changed 0
# L == H
# fullSet, iter: 0 i:596, pairs changed 0
# L == H
# fullSet, iter: 0 i:597, pairs changed 0
# L == H
# fullSet, iter: 0 i:598, pairs changed 0
# L == H
# fullSet, iter: 0 i:599, pairs changed 0
# L == H
# fullSet, iter: 0 i:600, pairs changed 0
# L == H
# fullSet, iter: 0 i:601, pairs changed 0
# L == H
# fullSet, iter: 0 i:602, pairs changed 0
# L == H
# fullSet, iter: 0 i:603, pairs changed 0
# L == H
# fullSet, iter: 0 i:604, pairs changed 0
# L == H
# fullSet, iter: 0 i:605, pairs changed 0
# L == H
# fullSet, iter: 0 i:606, pairs changed 0
# L == H
# fullSet, iter: 0 i:607, pairs changed 0
# L == H
# fullSet, iter: 0 i:608, pairs changed 0
# L == H
# fullSet, iter: 0 i:609, pairs changed 0
# L == H
# fullSet, iter: 0 i:610, pairs changed 0
# L == H
# fullSet, iter: 0 i:611, pairs changed 0
# L == H
# fullSet, iter: 0 i:612, pairs changed 0
# L == H
# fullSet, iter: 0 i:613, pairs changed 0
# L == H
# fullSet, iter: 0 i:614, pairs changed 0
# L == H
# fullSet, iter: 0 i:615, pairs changed 0
# L == H
# fullSet, iter: 0 i:616, pairs changed 0
# L == H
# fullSet, iter: 0 i:617, pairs changed 0
# L == H
# fullSet, iter: 0 i:618, pairs changed 0
# L == H
# fullSet, iter: 0 i:619, pairs changed 0
# L == H
# fullSet, iter: 0 i:620, pairs changed 0
# L == H
# fullSet, iter: 0 i:621, pairs changed 0
# L == H
# fullSet, iter: 0 i:622, pairs changed 0
# L == H
# fullSet, iter: 0 i:623, pairs changed 0
# fullSet, iter: 0 i:624, pairs changed 0
# L == H
# fullSet, iter: 0 i:625, pairs changed 0
# L == H
# fullSet, iter: 0 i:626, pairs changed 0
# L == H
# fullSet, iter: 0 i:627, pairs changed 0
# L == H
# fullSet, iter: 0 i:628, pairs changed 0
# L == H
# fullSet, iter: 0 i:629, pairs changed 0
# L == H
# fullSet, iter: 0 i:630, pairs changed 0
# L == H
# fullSet, iter: 0 i:631, pairs changed 0
# L == H
# fullSet, iter: 0 i:632, pairs changed 0
# L == H
# fullSet, iter: 0 i:633, pairs changed 0
# L == H
# fullSet, iter: 0 i:634, pairs changed 0
# L == H
# fullSet, iter: 0 i:635, pairs changed 0
# L == H
# fullSet, iter: 0 i:636, pairs changed 0
# L == H
# fullSet, iter: 0 i:637, pairs changed 0
# L == H
# fullSet, iter: 0 i:638, pairs changed 0
# L == H
# fullSet, iter: 0 i:639, pairs changed 0
# L == H
# fullSet, iter: 0 i:640, pairs changed 0
# L == H
# fullSet, iter: 0 i:641, pairs changed 0
# L == H
# fullSet, iter: 0 i:642, pairs changed 0
# L == H
# fullSet, iter: 0 i:643, pairs changed 0
# L == H
# fullSet, iter: 0 i:644, pairs changed 0
# L == H
# fullSet, iter: 0 i:645, pairs changed 0
# L == H
# fullSet, iter: 0 i:646, pairs changed 0
# L == H
# fullSet, iter: 0 i:647, pairs changed 0
# L == H
# fullSet, iter: 0 i:648, pairs changed 0
# L == H
# fullSet, iter: 0 i:649, pairs changed 0
# L == H
# fullSet, iter: 0 i:650, pairs changed 0
# L == H
# fullSet, iter: 0 i:651, pairs changed 0
# L == H
# fullSet, iter: 0 i:652, pairs changed 0
# L == H
# fullSet, iter: 0 i:653, pairs changed 0
# L == H
# fullSet, iter: 0 i:654, pairs changed 0
# L == H
# fullSet, iter: 0 i:655, pairs changed 0
# L == H
# fullSet, iter: 0 i:656, pairs changed 0
# L == H
# fullSet, iter: 0 i:657, pairs changed 0
# L == H
# fullSet, iter: 0 i:658, pairs changed 0
# L == H
# fullSet, iter: 0 i:659, pairs changed 0
# L == H
# fullSet, iter: 0 i:660, pairs changed 0
# L == H
# fullSet, iter: 0 i:661, pairs changed 0
# L == H
# fullSet, iter: 0 i:662, pairs changed 0
# L == H
# fullSet, iter: 0 i:663, pairs changed 0
# L == H
# fullSet, iter: 0 i:664, pairs changed 0
# L == H
# fullSet, iter: 0 i:665, pairs changed 0
# fullSet, iter: 0 i:666, pairs changed 0
# L == H
# fullSet, iter: 0 i:667, pairs changed 0
# L == H
# fullSet, iter: 0 i:668, pairs changed 0
# L == H
# fullSet, iter: 0 i:669, pairs changed 0
# L == H
# fullSet, iter: 0 i:670, pairs changed 0
# L == H
# fullSet, iter: 0 i:671, pairs changed 0
# L == H
# fullSet, iter: 0 i:672, pairs changed 0
# L == H
# fullSet, iter: 0 i:673, pairs changed 0
# L == H
# fullSet, iter: 0 i:674, pairs changed 0
# fullSet, iter: 0 i:675, pairs changed 0
# L == H
# fullSet, iter: 0 i:676, pairs changed 0
# L == H
# fullSet, iter: 0 i:677, pairs changed 0
# L == H
# fullSet, iter: 0 i:678, pairs changed 0
# L == H
# fullSet, iter: 0 i:679, pairs changed 0
# L == H
# fullSet, iter: 0 i:680, pairs changed 0
# L == H
# fullSet, iter: 0 i:681, pairs changed 0
# L == H
# fullSet, iter: 0 i:682, pairs changed 0
# L == H
# fullSet, iter: 0 i:683, pairs changed 0
# L == H
# fullSet, iter: 0 i:684, pairs changed 0
# L == H
# fullSet, iter: 0 i:685, pairs changed 0
# L == H
# fullSet, iter: 0 i:686, pairs changed 0
# L == H
# fullSet, iter: 0 i:687, pairs changed 0
# L == H
# fullSet, iter: 0 i:688, pairs changed 0
# L == H
# fullSet, iter: 0 i:689, pairs changed 0
# L == H
# fullSet, iter: 0 i:690, pairs changed 0
# L == H
# fullSet, iter: 0 i:691, pairs changed 0
# L == H
# fullSet, iter: 0 i:692, pairs changed 0
# L == H
# fullSet, iter: 0 i:693, pairs changed 0
# L == H
# fullSet, iter: 0 i:694, pairs changed 0
# L == H
# fullSet, iter: 0 i:695, pairs changed 0
# L == H
# fullSet, iter: 0 i:696, pairs changed 0
# L == H
# fullSet, iter: 0 i:697, pairs changed 0
# L == H
# fullSet, iter: 0 i:698, pairs changed 0
# L == H
# fullSet, iter: 0 i:699, pairs changed 0
# j not moving enough
# fullSet, iter: 1 i:0, pairs changed 0
# j not moving enough
# fullSet, iter: 1 i:1, pairs changed 0
# j not moving enough
# fullSet, iter: 1 i:2, pairs changed 0
# j not moving enough
# fullSet, iter: 1 i:3, pairs changed 0
# j not moving enough
# fullSet, iter: 1 i:4, pairs changed 0
# j not moving enough
# fullSet, iter: 1 i:5, pairs changed 0
# j not moving enough
# fullSet, iter: 1 i:6, pairs changed 0
# L == H
# fullSet, iter: 1 i:7, pairs changed 0
# L == H
# fullSet, iter: 1 i:8, pairs changed 0
# L == H
# fullSet, iter: 1 i:9, pairs changed 0
# L == H
# fullSet, iter: 1 i:10, pairs changed 0
# L == H
# fullSet, iter: 1 i:11, pairs changed 0
# L == H
# fullSet, iter: 1 i:12, pairs changed 0
# L == H
# fullSet, iter: 1 i:13, pairs changed 0
# L == H
# fullSet, iter: 1 i:14, pairs changed 0
# L == H
# fullSet, iter: 1 i:15, pairs changed 0
# L == H
# fullSet, iter: 1 i:16, pairs changed 0
# L == H
# fullSet, iter: 1 i:17, pairs changed 0
# fullSet, iter: 1 i:18, pairs changed 0
# L == H
# fullSet, iter: 1 i:19, pairs changed 0
# L == H
# fullSet, iter: 1 i:20, pairs changed 0
# L == H
# fullSet, iter: 1 i:21, pairs changed 0
# L == H
# fullSet, iter: 1 i:22, pairs changed 0
# fullSet, iter: 1 i:23, pairs changed 0
# L == H
# fullSet, iter: 1 i:24, pairs changed 0
# L == H
# fullSet, iter: 1 i:25, pairs changed 0
# L == H
# fullSet, iter: 1 i:26, pairs changed 0
# L == H
# fullSet, iter: 1 i:27, pairs changed 0
# L == H
# fullSet, iter: 1 i:28, pairs changed 0
# L == H
# fullSet, iter: 1 i:29, pairs changed 0
# L == H
# fullSet, iter: 1 i:30, pairs changed 0
# L == H
# fullSet, iter: 1 i:31, pairs changed 0
# L == H
# fullSet, iter: 1 i:32, pairs changed 0
# L == H
# fullSet, iter: 1 i:33, pairs changed 0
# L == H
# fullSet, iter: 1 i:34, pairs changed 0
# L == H
# fullSet, iter: 1 i:35, pairs changed 0
# L == H
# fullSet, iter: 1 i:36, pairs changed 0
# L == H
# fullSet, iter: 1 i:37, pairs changed 0
# L == H
# fullSet, iter: 1 i:38, pairs changed 0
# L == H
# fullSet, iter: 1 i:39, pairs changed 0
# L == H
# fullSet, iter: 1 i:40, pairs changed 0
# L == H
# fullSet, iter: 1 i:41, pairs changed 0
# L == H
# fullSet, iter: 1 i:42, pairs changed 0
# L == H
# fullSet, iter: 1 i:43, pairs changed 0
# L == H
# fullSet, iter: 1 i:44, pairs changed 0
# L == H
# fullSet, iter: 1 i:45, pairs changed 0
# L == H
# fullSet, iter: 1 i:46, pairs changed 0
# L == H
# fullSet, iter: 1 i:47, pairs changed 0
# L == H
# fullSet, iter: 1 i:48, pairs changed 0
# L == H
# fullSet, iter: 1 i:49, pairs changed 0
# L == H
# fullSet, iter: 1 i:50, pairs changed 0
# L == H
# fullSet, iter: 1 i:51, pairs changed 0
# L == H
# fullSet, iter: 1 i:52, pairs changed 0
# L == H
# fullSet, iter: 1 i:53, pairs changed 0
# L == H
# fullSet, iter: 1 i:54, pairs changed 0
# L == H
# fullSet, iter: 1 i:55, pairs changed 0
# L == H
# fullSet, iter: 1 i:56, pairs changed 0
# L == H
# fullSet, iter: 1 i:57, pairs changed 0
# L == H
# fullSet, iter: 1 i:58, pairs changed 0
# L == H
# fullSet, iter: 1 i:59, pairs changed 0
# L == H
# fullSet, iter: 1 i:60, pairs changed 0
# L == H
# fullSet, iter: 1 i:61, pairs changed 0
# L == H
# fullSet, iter: 1 i:62, pairs changed 0
# L == H
# fullSet, iter: 1 i:63, pairs changed 0
# L == H
# fullSet, iter: 1 i:64, pairs changed 0
# L == H
# fullSet, iter: 1 i:65, pairs changed 0
# L == H
# fullSet, iter: 1 i:66, pairs changed 0
# L == H
# fullSet, iter: 1 i:67, pairs changed 0
# L == H
# fullSet, iter: 1 i:68, pairs changed 0
# L == H
# fullSet, iter: 1 i:69, pairs changed 0
# L == H
# fullSet, iter: 1 i:70, pairs changed 0
# L == H
# fullSet, iter: 1 i:71, pairs changed 0
# L == H
# fullSet, iter: 1 i:72, pairs changed 0
# L == H
# fullSet, iter: 1 i:73, pairs changed 0
# L == H
# fullSet, iter: 1 i:74, pairs changed 0
# L == H
# fullSet, iter: 1 i:75, pairs changed 0
# L == H
# fullSet, iter: 1 i:76, pairs changed 0
# L == H
# fullSet, iter: 1 i:77, pairs changed 0
# L == H
# fullSet, iter: 1 i:78, pairs changed 0
# fullSet, iter: 1 i:79, pairs changed 0
# L == H
# fullSet, iter: 1 i:80, pairs changed 0
# L == H
# fullSet, iter: 1 i:81, pairs changed 0
# L == H
# fullSet, iter: 1 i:82, pairs changed 0
# L == H
# fullSet, iter: 1 i:83, pairs changed 0
# L == H
# fullSet, iter: 1 i:84, pairs changed 0
# L == H
# fullSet, iter: 1 i:85, pairs changed 0
# L == H
# fullSet, iter: 1 i:86, pairs changed 0
# L == H
# fullSet, iter: 1 i:87, pairs changed 0
# L == H
# fullSet, iter: 1 i:88, pairs changed 0
# L == H
# fullSet, iter: 1 i:89, pairs changed 0
# L == H
# fullSet, iter: 1 i:90, pairs changed 0
# L == H
# fullSet, iter: 1 i:91, pairs changed 0
# L == H
# fullSet, iter: 1 i:92, pairs changed 0
# L == H
# fullSet, iter: 1 i:93, pairs changed 0
# L == H
# fullSet, iter: 1 i:94, pairs changed 0
# L == H
# fullSet, iter: 1 i:95, pairs changed 0
# L == H
# fullSet, iter: 1 i:96, pairs changed 0
# L == H
# fullSet, iter: 1 i:97, pairs changed 0
# L == H
# fullSet, iter: 1 i:98, pairs changed 0
# L == H
# fullSet, iter: 1 i:99, pairs changed 0
# L == H
# fullSet, iter: 1 i:100, pairs changed 0
# L == H
# fullSet, iter: 1 i:101, pairs changed 0
# L == H
# fullSet, iter: 1 i:102, pairs changed 0
# L == H
# fullSet, iter: 1 i:103, pairs changed 0
# fullSet, iter: 1 i:104, pairs changed 0
# L == H
# fullSet, iter: 1 i:105, pairs changed 0
# L == H
# fullSet, iter: 1 i:106, pairs changed 0
# L == H
# fullSet, iter: 1 i:107, pairs changed 0
# L == H
# fullSet, iter: 1 i:108, pairs changed 0
# L == H
# fullSet, iter: 1 i:109, pairs changed 0
# L == H
# fullSet, iter: 1 i:110, pairs changed 0
# L == H
# fullSet, iter: 1 i:111, pairs changed 0
# L == H
# fullSet, iter: 1 i:112, pairs changed 0
# L == H
# fullSet, iter: 1 i:113, pairs changed 0
# L == H
# fullSet, iter: 1 i:114, pairs changed 0
# L == H
# fullSet, iter: 1 i:115, pairs changed 0
# L == H
# fullSet, iter: 1 i:116, pairs changed 0
# fullSet, iter: 1 i:117, pairs changed 0
# L == H
# fullSet, iter: 1 i:118, pairs changed 0
# L == H
# fullSet, iter: 1 i:119, pairs changed 0
# L == H
# fullSet, iter: 1 i:120, pairs changed 0
# L == H
# fullSet, iter: 1 i:121, pairs changed 0
# L == H
# fullSet, iter: 1 i:122, pairs changed 0
# L == H
# fullSet, iter: 1 i:123, pairs changed 0
# L == H
# fullSet, iter: 1 i:124, pairs changed 0
# L == H
# fullSet, iter: 1 i:125, pairs changed 0
# L == H
# fullSet, iter: 1 i:126, pairs changed 0
# L == H
# fullSet, iter: 1 i:127, pairs changed 0
# L == H
# fullSet, iter: 1 i:128, pairs changed 0
# L == H
# fullSet, iter: 1 i:129, pairs changed 0
# L == H
# fullSet, iter: 1 i:130, pairs changed 0
# L == H
# fullSet, iter: 1 i:131, pairs changed 0
# L == H
# fullSet, iter: 1 i:132, pairs changed 0
# L == H
# fullSet, iter: 1 i:133, pairs changed 0
# L == H
# fullSet, iter: 1 i:134, pairs changed 0
# L == H
# fullSet, iter: 1 i:135, pairs changed 0
# L == H
# fullSet, iter: 1 i:136, pairs changed 0
# L == H
# fullSet, iter: 1 i:137, pairs changed 0
# L == H
# fullSet, iter: 1 i:138, pairs changed 0
# L == H
# fullSet, iter: 1 i:139, pairs changed 0
# L == H
# fullSet, iter: 1 i:140, pairs changed 0
# L == H
# fullSet, iter: 1 i:141, pairs changed 0
# L == H
# fullSet, iter: 1 i:142, pairs changed 0
# L == H
# fullSet, iter: 1 i:143, pairs changed 0
# L == H
# fullSet, iter: 1 i:144, pairs changed 0
# L == H
# fullSet, iter: 1 i:145, pairs changed 0
# L == H
# fullSet, iter: 1 i:146, pairs changed 0
# L == H
# fullSet, iter: 1 i:147, pairs changed 0
# L == H
# fullSet, iter: 1 i:148, pairs changed 0
# L == H
# fullSet, iter: 1 i:149, pairs changed 0
# L == H
# fullSet, iter: 1 i:150, pairs changed 0
# L == H
# fullSet, iter: 1 i:151, pairs changed 0
# L == H
# fullSet, iter: 1 i:152, pairs changed 0
# L == H
# fullSet, iter: 1 i:153, pairs changed 0
# L == H
# fullSet, iter: 1 i:154, pairs changed 0
# L == H
# fullSet, iter: 1 i:155, pairs changed 0
# L == H
# fullSet, iter: 1 i:156, pairs changed 0
# L == H
# fullSet, iter: 1 i:157, pairs changed 0
# L == H
# fullSet, iter: 1 i:158, pairs changed 0
# L == H
# fullSet, iter: 1 i:159, pairs changed 0
# L == H
# fullSet, iter: 1 i:160, pairs changed 0
# L == H
# fullSet, iter: 1 i:161, pairs changed 0
# L == H
# fullSet, iter: 1 i:162, pairs changed 0
# L == H
# fullSet, iter: 1 i:163, pairs changed 0
# L == H
# fullSet, iter: 1 i:164, pairs changed 0
# L == H
# fullSet, iter: 1 i:165, pairs changed 0
# L == H
# fullSet, iter: 1 i:166, pairs changed 0
# L == H
# fullSet, iter: 1 i:167, pairs changed 0
# fullSet, iter: 1 i:168, pairs changed 0
# L == H
# fullSet, iter: 1 i:169, pairs changed 0
# L == H
# fullSet, iter: 1 i:170, pairs changed 0
# L == H
# fullSet, iter: 1 i:171, pairs changed 0
# L == H
# fullSet, iter: 1 i:172, pairs changed 0
# L == H
# fullSet, iter: 1 i:173, pairs changed 0
# fullSet, iter: 1 i:174, pairs changed 0
# L == H
# fullSet, iter: 1 i:175, pairs changed 0
# L == H
# fullSet, iter: 1 i:176, pairs changed 0
# L == H
# fullSet, iter: 1 i:177, pairs changed 0
# L == H
# fullSet, iter: 1 i:178, pairs changed 0
# L == H
# fullSet, iter: 1 i:179, pairs changed 0
# L == H
# fullSet, iter: 1 i:180, pairs changed 0
# L == H
# fullSet, iter: 1 i:181, pairs changed 0
# L == H
# fullSet, iter: 1 i:182, pairs changed 0
# L == H
# fullSet, iter: 1 i:183, pairs changed 0
# L == H
# fullSet, iter: 1 i:184, pairs changed 0
# L == H
# fullSet, iter: 1 i:185, pairs changed 0
# L == H
# fullSet, iter: 1 i:186, pairs changed 0
# L == H
# fullSet, iter: 1 i:187, pairs changed 0
# L == H
# fullSet, iter: 1 i:188, pairs changed 0
# L == H
# fullSet, iter: 1 i:189, pairs changed 0
# L == H
# fullSet, iter: 1 i:190, pairs changed 0
# fullSet, iter: 1 i:191, pairs changed 0
# L == H
# fullSet, iter: 1 i:192, pairs changed 0
# L == H
# fullSet, iter: 1 i:193, pairs changed 0
# L == H
# fullSet, iter: 1 i:194, pairs changed 0
# L == H
# fullSet, iter: 1 i:195, pairs changed 0
# L == H
# fullSet, iter: 1 i:196, pairs changed 0
# L == H
# fullSet, iter: 1 i:197, pairs changed 0
# L == H
# fullSet, iter: 1 i:198, pairs changed 0
# L == H
# fullSet, iter: 1 i:199, pairs changed 0
# L == H
# fullSet, iter: 1 i:200, pairs changed 0
# L == H
# fullSet, iter: 1 i:201, pairs changed 0
# L == H
# fullSet, iter: 1 i:202, pairs changed 0
# L == H
# fullSet, iter: 1 i:203, pairs changed 0
# L == H
# fullSet, iter: 1 i:204, pairs changed 0
# L == H
# fullSet, iter: 1 i:205, pairs changed 0
# L == H
# fullSet, iter: 1 i:206, pairs changed 0
# L == H
# fullSet, iter: 1 i:207, pairs changed 0
# L == H
# fullSet, iter: 1 i:208, pairs changed 0
# L == H
# fullSet, iter: 1 i:209, pairs changed 0
# L == H
# fullSet, iter: 1 i:210, pairs changed 0
# L == H
# fullSet, iter: 1 i:211, pairs changed 0
# L == H
# fullSet, iter: 1 i:212, pairs changed 0
# L == H
# fullSet, iter: 1 i:213, pairs changed 0
# L == H
# fullSet, iter: 1 i:214, pairs changed 0
# L == H
# fullSet, iter: 1 i:215, pairs changed 0
# L == H
# fullSet, iter: 1 i:216, pairs changed 0
# L == H
# fullSet, iter: 1 i:217, pairs changed 0
# L == H
# fullSet, iter: 1 i:218, pairs changed 0
# L == H
# fullSet, iter: 1 i:219, pairs changed 0
# L == H
# fullSet, iter: 1 i:220, pairs changed 0
# L == H
# fullSet, iter: 1 i:221, pairs changed 0
# L == H
# fullSet, iter: 1 i:222, pairs changed 0
# L == H
# fullSet, iter: 1 i:223, pairs changed 0
# L == H
# fullSet, iter: 1 i:224, pairs changed 0
# L == H
# fullSet, iter: 1 i:225, pairs changed 0
# L == H
# fullSet, iter: 1 i:226, pairs changed 0
# L == H
# fullSet, iter: 1 i:227, pairs changed 0
# L == H
# fullSet, iter: 1 i:228, pairs changed 0
# L == H
# fullSet, iter: 1 i:229, pairs changed 0
# L == H
# fullSet, iter: 1 i:230, pairs changed 0
# L == H
# fullSet, iter: 1 i:231, pairs changed 0
# L == H
# fullSet, iter: 1 i:232, pairs changed 0
# L == H
# fullSet, iter: 1 i:233, pairs changed 0
# L == H
# fullSet, iter: 1 i:234, pairs changed 0
# L == H
# fullSet, iter: 1 i:235, pairs changed 0
# L == H
# fullSet, iter: 1 i:236, pairs changed 0
# L == H
# fullSet, iter: 1 i:237, pairs changed 0
# L == H
# fullSet, iter: 1 i:238, pairs changed 0
# L == H
# fullSet, iter: 1 i:239, pairs changed 0
# L == H
# fullSet, iter: 1 i:240, pairs changed 0
# L == H
# fullSet, iter: 1 i:241, pairs changed 0
# L == H
# fullSet, iter: 1 i:242, pairs changed 0
# L == H
# fullSet, iter: 1 i:243, pairs changed 0
# L == H
# fullSet, iter: 1 i:244, pairs changed 0
# L == H
# fullSet, iter: 1 i:245, pairs changed 0
# L == H
# fullSet, iter: 1 i:246, pairs changed 0
# L == H
# fullSet, iter: 1 i:247, pairs changed 0
# L == H
# fullSet, iter: 1 i:248, pairs changed 0
# L == H
# fullSet, iter: 1 i:249, pairs changed 0
# L == H
# fullSet, iter: 1 i:250, pairs changed 0
# L == H
# fullSet, iter: 1 i:251, pairs changed 0
# L == H
# fullSet, iter: 1 i:252, pairs changed 0
# L == H
# fullSet, iter: 1 i:253, pairs changed 0
# L == H
# fullSet, iter: 1 i:254, pairs changed 0
# L == H
# fullSet, iter: 1 i:255, pairs changed 0
# L == H
# fullSet, iter: 1 i:256, pairs changed 0
# fullSet, iter: 1 i:257, pairs changed 0
# L == H
# fullSet, iter: 1 i:258, pairs changed 0
# L == H
# fullSet, iter: 1 i:259, pairs changed 0
# L == H
# fullSet, iter: 1 i:260, pairs changed 0
# L == H
# fullSet, iter: 1 i:261, pairs changed 0
# L == H
# fullSet, iter: 1 i:262, pairs changed 0
# L == H
# fullSet, iter: 1 i:263, pairs changed 0
# L == H
# fullSet, iter: 1 i:264, pairs changed 0
# L == H
# fullSet, iter: 1 i:265, pairs changed 0
# L == H
# fullSet, iter: 1 i:266, pairs changed 0
# L == H
# fullSet, iter: 1 i:267, pairs changed 0
# L == H
# fullSet, iter: 1 i:268, pairs changed 0
# L == H
# fullSet, iter: 1 i:269, pairs changed 0
# L == H
# fullSet, iter: 1 i:270, pairs changed 0
# L == H
# fullSet, iter: 1 i:271, pairs changed 0
# L == H
# fullSet, iter: 1 i:272, pairs changed 0
# L == H
# fullSet, iter: 1 i:273, pairs changed 0
# L == H
# fullSet, iter: 1 i:274, pairs changed 0
# L == H
# fullSet, iter: 1 i:275, pairs changed 0
# L == H
# fullSet, iter: 1 i:276, pairs changed 0
# L == H
# fullSet, iter: 1 i:277, pairs changed 0
# L == H
# fullSet, iter: 1 i:278, pairs changed 0
# L == H
# fullSet, iter: 1 i:279, pairs changed 0
# L == H
# fullSet, iter: 1 i:280, pairs changed 0
# L == H
# fullSet, iter: 1 i:281, pairs changed 0
# L == H
# fullSet, iter: 1 i:282, pairs changed 0
# L == H
# fullSet, iter: 1 i:283, pairs changed 0
# L == H
# fullSet, iter: 1 i:284, pairs changed 0
# L == H
# fullSet, iter: 1 i:285, pairs changed 0
# L == H
# fullSet, iter: 1 i:286, pairs changed 0
# L == H
# fullSet, iter: 1 i:287, pairs changed 0
# L == H
# fullSet, iter: 1 i:288, pairs changed 0
# L == H
# fullSet, iter: 1 i:289, pairs changed 0
# L == H
# fullSet, iter: 1 i:290, pairs changed 0
# L == H
# fullSet, iter: 1 i:291, pairs changed 0
# L == H
# fullSet, iter: 1 i:292, pairs changed 0
# L == H
# fullSet, iter: 1 i:293, pairs changed 0
# L == H
# fullSet, iter: 1 i:294, pairs changed 0
# L == H
# fullSet, iter: 1 i:295, pairs changed 0
# L == H
# fullSet, iter: 1 i:296, pairs changed 0
# L == H
# fullSet, iter: 1 i:297, pairs changed 0
# L == H
# fullSet, iter: 1 i:298, pairs changed 0
# L == H
# fullSet, iter: 1 i:299, pairs changed 0
# L == H
# fullSet, iter: 1 i:300, pairs changed 0
# L == H
# fullSet, iter: 1 i:301, pairs changed 0
# L == H
# fullSet, iter: 1 i:302, pairs changed 0
# L == H
# fullSet, iter: 1 i:303, pairs changed 0
# L == H
# fullSet, iter: 1 i:304, pairs changed 0
# L == H
# fullSet, iter: 1 i:305, pairs changed 0
# L == H
# fullSet, iter: 1 i:306, pairs changed 0
# L == H
# fullSet, iter: 1 i:307, pairs changed 0
# L == H
# fullSet, iter: 1 i:308, pairs changed 0
# L == H
# fullSet, iter: 1 i:309, pairs changed 0
# L == H
# fullSet, iter: 1 i:310, pairs changed 0
# L == H
# fullSet, iter: 1 i:311, pairs changed 0
# L == H
# fullSet, iter: 1 i:312, pairs changed 0
# L == H
# fullSet, iter: 1 i:313, pairs changed 0
# L == H
# fullSet, iter: 1 i:314, pairs changed 0
# L == H
# fullSet, iter: 1 i:315, pairs changed 0
# L == H
# fullSet, iter: 1 i:316, pairs changed 0
# L == H
# fullSet, iter: 1 i:317, pairs changed 0
# L == H
# fullSet, iter: 1 i:318, pairs changed 0
# L == H
# fullSet, iter: 1 i:319, pairs changed 0
# L == H
# fullSet, iter: 1 i:320, pairs changed 0
# L == H
# ...
# L == H
# fullSet, iter: 2 i:358, pairs changed 0
# L == H
# fullSet, iter: 2 i:359, pairs changed 0
# L == H
# fullSet, iter: 2 i:360, pairs changed 0
# L == H
# fullSet, iter: 2 i:361, pairs changed 0
# L == H
# fullSet, iter: 2 i:362, pairs changed 0
# L == H
# fullSet, iter: 2 i:363, pairs changed 0
# L == H
# fullSet, iter: 2 i:364, pairs changed 0
# L == H
# fullSet, iter: 2 i:365, pairs changed 0
# L == H
# fullSet, iter: 2 i:366, pairs changed 0
# L == H
# fullSet, iter: 2 i:367, pairs changed 0
# L == H
# fullSet, iter: 2 i:368, pairs changed 0
# L == H
# fullSet, iter: 2 i:369, pairs changed 0
# L == H
# fullSet, iter: 2 i:370, pairs changed 0
# L == H
# fullSet, iter: 2 i:371, pairs changed 0
# L == H
# fullSet, iter: 2 i:372, pairs changed 0
# L == H
# fullSet, iter: 2 i:373, pairs changed 0
# L == H
# fullSet, iter: 2 i:374, pairs changed 0
# L == H
# fullSet, iter: 2 i:375, pairs changed 0
# L == H
# fullSet, iter: 2 i:376, pairs changed 0
# L == H
# fullSet, iter: 2 i:377, pairs changed 0
# L == H
# fullSet, iter: 2 i:378, pairs changed 0
# L == H
# fullSet, iter: 2 i:379, pairs changed 0
# L == H
# fullSet, iter: 2 i:380, pairs changed 0
# L == H
# fullSet, iter: 2 i:381, pairs changed 0
# L == H
# fullSet, iter: 2 i:382, pairs changed 0
# L == H
# fullSet, iter: 2 i:383, pairs changed 0
# L == H
# fullSet, iter: 2 i:384, pairs changed 0
# L == H
# fullSet, iter: 2 i:385, pairs changed 0
# L == H
# fullSet, iter: 2 i:386, pairs changed 0
# L == H
# fullSet, iter: 2 i:387, pairs changed 0
# L == H
# fullSet, iter: 2 i:388, pairs changed 0
# L == H
# fullSet, iter: 2 i:389, pairs changed 0
# L == H
# fullSet, iter: 2 i:390, pairs changed 0
# L == H
# fullSet, iter: 2 i:391, pairs changed 0
# L == H
# fullSet, iter: 2 i:392, pairs changed 0
# L == H
# fullSet, iter: 2 i:393, pairs changed 0
# L == H
# fullSet, iter: 2 i:394, pairs changed 0
# L == H
# fullSet, iter: 2 i:395, pairs changed 0
# L == H
# fullSet, iter: 2 i:396, pairs changed 0
# L == H
# fullSet, iter: 2 i:397, pairs changed 0
# L == H
# fullSet, iter: 2 i:398, pairs changed 0
# L == H
# fullSet, iter: 2 i:399, pairs changed 0
# L == H
# fullSet, iter: 2 i:400, pairs changed 0
# L == H
# fullSet, iter: 2 i:401, pairs changed 0
# L == H
# fullSet, iter: 2 i:402, pairs changed 0
# L == H
# fullSet, iter: 2 i:403, pairs changed 0
# L == H
# fullSet, iter: 2 i:404, pairs changed 0
# L == H
# fullSet, iter: 2 i:405, pairs changed 0
# L == H
# fullSet, iter: 2 i:406, pairs changed 0
# L == H
# fullSet, iter: 2 i:407, pairs changed 0
# L == H
# fullSet, iter: 2 i:408, pairs changed 0
# L == H
# fullSet, iter: 2 i:409, pairs changed 0
# L == H
# fullSet, iter: 2 i:410, pairs changed 0
# L == H
# fullSet, iter: 2 i:411, pairs changed 0
# L == H
# fullSet, iter: 2 i:412, pairs changed 0
# L == H
# fullSet, iter: 2 i:413, pairs changed 0
# L == H
# fullSet, iter: 2 i:414, pairs changed 0
# L == H
# fullSet, iter: 2 i:415, pairs changed 0
# fullSet, iter: 2 i:416, pairs changed 0
# L == H
# fullSet, iter: 2 i:417, pairs changed 0
# L == H
# fullSet, iter: 2 i:418, pairs changed 0
# L == H
# fullSet, iter: 2 i:419, pairs changed 0
# L == H
# fullSet, iter: 2 i:420, pairs changed 0
# L == H
# fullSet, iter: 2 i:421, pairs changed 0
# L == H
# fullSet, iter: 2 i:422, pairs changed 0
# L == H
# fullSet, iter: 2 i:423, pairs changed 0
# L == H
# fullSet, iter: 2 i:424, pairs changed 0
# L == H
# fullSet, iter: 2 i:425, pairs changed 0
# L == H
# fullSet, iter: 2 i:426, pairs changed 0
# L == H
# fullSet, iter: 2 i:427, pairs changed 0
# L == H
# fullSet, iter: 2 i:428, pairs changed 0
# L == H
# fullSet, iter: 2 i:429, pairs changed 0
# L == H
# fullSet, iter: 2 i:430, pairs changed 0
# L == H
# fullSet, iter: 2 i:431, pairs changed 0
# fullSet, iter: 2 i:432, pairs changed 0
# L == H
# fullSet, iter: 2 i:433, pairs changed 0
# L == H
# fullSet, iter: 2 i:434, pairs changed 0
# L == H
# fullSet, iter: 2 i:435, pairs changed 0
# L == H
# fullSet, iter: 2 i:436, pairs changed 0
# L == H
# fullSet, iter: 2 i:437, pairs changed 0
# L == H
# fullSet, iter: 2 i:438, pairs changed 0
# L == H
# fullSet, iter: 2 i:439, pairs changed 0
# L == H
# fullSet, iter: 2 i:440, pairs changed 0
# L == H
# fullSet, iter: 2 i:441, pairs changed 0
# L == H
# fullSet, iter: 2 i:442, pairs changed 0
# L == H
# fullSet, iter: 2 i:443, pairs changed 0
# L == H
# fullSet, iter: 2 i:444, pairs changed 0
# L == H
# fullSet, iter: 2 i:445, pairs changed 0
# L == H
# fullSet, iter: 2 i:446, pairs changed 0
# L == H
# fullSet, iter: 2 i:447, pairs changed 0
# L == H
# fullSet, iter: 2 i:448, pairs changed 0
# L == H
# fullSet, iter: 2 i:449, pairs changed 0
# L == H
# fullSet, iter: 2 i:450, pairs changed 0
# L == H
# fullSet, iter: 2 i:451, pairs changed 0
# L == H
# fullSet, iter: 2 i:452, pairs changed 0
# L == H
# fullSet, iter: 2 i:453, pairs changed 0
# L == H
# fullSet, iter: 2 i:454, pairs changed 0
# L == H
# fullSet, iter: 2 i:455, pairs changed 0
# L == H
# fullSet, iter: 2 i:456, pairs changed 0
# fullSet, iter: 2 i:457, pairs changed 0
# L == H
# fullSet, iter: 2 i:458, pairs changed 0
# L == H
# fullSet, iter: 2 i:459, pairs changed 0
# L == H
# fullSet, iter: 2 i:460, pairs changed 0
# L == H
# fullSet, iter: 2 i:461, pairs changed 0
# L == H
# fullSet, iter: 2 i:462, pairs changed 0
# L == H
# fullSet, iter: 2 i:463, pairs changed 0
# L == H
# fullSet, iter: 2 i:464, pairs changed 0
# L == H
# fullSet, iter: 2 i:465, pairs changed 0
# L == H
# fullSet, iter: 2 i:466, pairs changed 0
# L == H
# fullSet, iter: 2 i:467, pairs changed 0
# L == H
# fullSet, iter: 2 i:468, pairs changed 0
# L == H
# fullSet, iter: 2 i:469, pairs changed 0
# L == H
# fullSet, iter: 2 i:470, pairs changed 0
# L == H
# fullSet, iter: 2 i:471, pairs changed 0
# L == H
# fullSet, iter: 2 i:472, pairs changed 0
# L == H
# fullSet, iter: 2 i:473, pairs changed 0
# L == H
# fullSet, iter: 2 i:474, pairs changed 0
# L == H
# fullSet, iter: 2 i:475, pairs changed 0
# L == H
# fullSet, iter: 2 i:476, pairs changed 0
# L == H
# fullSet, iter: 2 i:477, pairs changed 0
# L == H
# fullSet, iter: 2 i:478, pairs changed 0
# L == H
# fullSet, iter: 2 i:479, pairs changed 0
# fullSet, iter: 2 i:480, pairs changed 0
# L == H
# fullSet, iter: 2 i:481, pairs changed 0
# L == H
# fullSet, iter: 2 i:482, pairs changed 0
# L == H
# fullSet, iter: 2 i:483, pairs changed 0
# fullSet, iter: 2 i:484, pairs changed 0
# L == H
# fullSet, iter: 2 i:485, pairs changed 0
# L == H
# fullSet, iter: 2 i:486, pairs changed 0
# L == H
# fullSet, iter: 2 i:487, pairs changed 0
# L == H
# fullSet, iter: 2 i:488, pairs changed 0
# L == H
# fullSet, iter: 2 i:489, pairs changed 0
# L == H
# fullSet, iter: 2 i:490, pairs changed 0
# L == H
# fullSet, iter: 2 i:491, pairs changed 0
# L == H
# fullSet, iter: 2 i:492, pairs changed 0
# L == H
# fullSet, iter: 2 i:493, pairs changed 0
# L == H
# fullSet, iter: 2 i:494, pairs changed 0
# L == H
# fullSet, iter: 2 i:495, pairs changed 0
# L == H
# fullSet, iter: 2 i:496, pairs changed 0
# L == H
# fullSet, iter: 2 i:497, pairs changed 0
# L == H
# fullSet, iter: 2 i:498, pairs changed 0
# L == H
# fullSet, iter: 2 i:499, pairs changed 0
# L == H
# fullSet, iter: 2 i:500, pairs changed 0
# L == H
# fullSet, iter: 2 i:501, pairs changed 0
# L == H
# fullSet, iter: 2 i:502, pairs changed 0
# L == H
# fullSet, iter: 2 i:503, pairs changed 0
# fullSet, iter: 2 i:504, pairs changed 0
# L == H
# fullSet, iter: 2 i:505, pairs changed 0
# L == H
# fullSet, iter: 2 i:506, pairs changed 0
# L == H
# fullSet, iter: 2 i:507, pairs changed 0
# L == H
# fullSet, iter: 2 i:508, pairs changed 0
# L == H
# fullSet, iter: 2 i:509, pairs changed 0
# L == H
# fullSet, iter: 2 i:510, pairs changed 0
# L == H
# fullSet, iter: 2 i:511, pairs changed 0
# L == H
# fullSet, iter: 2 i:512, pairs changed 0
# L == H
# fullSet, iter: 2 i:513, pairs changed 0
# L == H
# fullSet, iter: 2 i:514, pairs changed 0
# L == H
# fullSet, iter: 2 i:515, pairs changed 0
# L == H
# fullSet, iter: 2 i:516, pairs changed 0
# L == H
# fullSet, iter: 2 i:517, pairs changed 0
# L == H
# fullSet, iter: 2 i:518, pairs changed 0
# L == H
# fullSet, iter: 2 i:519, pairs changed 0
# L == H
# fullSet, iter: 2 i:520, pairs changed 0
# L == H
# fullSet, iter: 2 i:521, pairs changed 0
# L == H
# fullSet, iter: 2 i:522, pairs changed 0
# fullSet, iter: 2 i:523, pairs changed 0
# L == H
# fullSet, iter: 2 i:524, pairs changed 0
# L == H
# fullSet, iter: 2 i:525, pairs changed 0
# L == H
# fullSet, iter: 2 i:526, pairs changed 0
# L == H
# fullSet, iter: 2 i:527, pairs changed 0
# L == H
# fullSet, iter: 2 i:528, pairs changed 0
# L == H
# fullSet, iter: 2 i:529, pairs changed 0
# L == H
# fullSet, iter: 2 i:530, pairs changed 0
# fullSet, iter: 2 i:531, pairs changed 0
# L == H
# fullSet, iter: 2 i:532, pairs changed 0
# L == H
# fullSet, iter: 2 i:533, pairs changed 0
# L == H
# fullSet, iter: 2 i:534, pairs changed 0
# L == H
# fullSet, iter: 2 i:535, pairs changed 0
# fullSet, iter: 2 i:536, pairs changed 0
# L == H
# fullSet, iter: 2 i:537, pairs changed 0
# L == H
# fullSet, iter: 2 i:538, pairs changed 0
# L == H
# fullSet, iter: 2 i:539, pairs changed 0
# L == H
# fullSet, iter: 2 i:540, pairs changed 0
# L == H
# fullSet, iter: 2 i:541, pairs changed 0
# L == H
# fullSet, iter: 2 i:542, pairs changed 0
# L == H
# fullSet, iter: 2 i:543, pairs changed 0
# L == H
# fullSet, iter: 2 i:544, pairs changed 0
# L == H
# fullSet, iter: 2 i:545, pairs changed 0
# L == H
# fullSet, iter: 2 i:546, pairs changed 0
# L == H
# fullSet, iter: 2 i:547, pairs changed 0
# L == H
# fullSet, iter: 2 i:548, pairs changed 0
# L == H
# fullSet, iter: 2 i:549, pairs changed 0
# L == H
# fullSet, iter: 2 i:550, pairs changed 0
# L == H
# fullSet, iter: 2 i:551, pairs changed 0
# L == H
# fullSet, iter: 2 i:552, pairs changed 0
# L == H
# fullSet, iter: 2 i:553, pairs changed 0
# L == H
# fullSet, iter: 2 i:554, pairs changed 0
# L == H
# fullSet, iter: 2 i:555, pairs changed 0
# L == H
# fullSet, iter: 2 i:556, pairs changed 0
# L == H
# fullSet, iter: 2 i:557, pairs changed 0
# L == H
# fullSet, iter: 2 i:558, pairs changed 0
# L == H
# fullSet, iter: 2 i:559, pairs changed 0
# L == H
# fullSet, iter: 2 i:560, pairs changed 0
# L == H
# fullSet, iter: 2 i:561, pairs changed 0
# L == H
# fullSet, iter: 2 i:562, pairs changed 0
# L == H
# fullSet, iter: 2 i:563, pairs changed 0
# L == H
# fullSet, iter: 2 i:564, pairs changed 0
# L == H
# fullSet, iter: 2 i:565, pairs changed 0
# L == H
# fullSet, iter: 2 i:566, pairs changed 0
# L == H
# fullSet, iter: 2 i:567, pairs changed 0
# L == H
# fullSet, iter: 2 i:568, pairs changed 0
# L == H
# fullSet, iter: 2 i:569, pairs changed 0
# L == H
# fullSet, iter: 2 i:570, pairs changed 0
# L == H
# fullSet, iter: 2 i:571, pairs changed 0
# L == H
# fullSet, iter: 2 i:572, pairs changed 0
# L == H
# fullSet, iter: 2 i:573, pairs changed 0
# L == H
# fullSet, iter: 2 i:574, pairs changed 0
# L == H
# fullSet, iter: 2 i:575, pairs changed 0
# L == H
# fullSet, iter: 2 i:576, pairs changed 0
# L == H
# fullSet, iter: 2 i:577, pairs changed 0
# L == H
# fullSet, iter: 2 i:578, pairs changed 0
# L == H
# fullSet, iter: 2 i:579, pairs changed 0
# L == H
# fullSet, iter: 2 i:580, pairs changed 0
# L == H
# fullSet, iter: 2 i:581, pairs changed 0
# L == H
# fullSet, iter: 2 i:582, pairs changed 0
# L == H
# fullSet, iter: 2 i:583, pairs changed 0
# L == H
# fullSet, iter: 2 i:584, pairs changed 0
# L == H
# fullSet, iter: 2 i:585, pairs changed 0
# L == H
# fullSet, iter: 2 i:586, pairs changed 0
# L == H
# fullSet, iter: 2 i:587, pairs changed 0
# L == H
# fullSet, iter: 2 i:588, pairs changed 0
# L == H
# fullSet, iter: 2 i:589, pairs changed 0
# L == H
# fullSet, iter: 2 i:590, pairs changed 0
# L == H
# fullSet, iter: 2 i:591, pairs changed 0
# L == H
# fullSet, iter: 2 i:592, pairs changed 0
# L == H
# fullSet, iter: 2 i:593, pairs changed 0
# L == H
# fullSet, iter: 2 i:594, pairs changed 0
# L == H
# fullSet, iter: 2 i:595, pairs changed 0
# L == H
# fullSet, iter: 2 i:596, pairs changed 0
# L == H
# fullSet, iter: 2 i:597, pairs changed 0
# L == H
# fullSet, iter: 2 i:598, pairs changed 0
# L == H
# fullSet, iter: 2 i:599, pairs changed 0
# fullSet, iter: 2 i:600, pairs changed 0
# L == H
# fullSet, iter: 2 i:601, pairs changed 0
# L == H
# fullSet, iter: 2 i:602, pairs changed 0
# L == H
# fullSet, iter: 2 i:603, pairs changed 0
# L == H
# fullSet, iter: 2 i:604, pairs changed 0
# L == H
# fullSet, iter: 2 i:605, pairs changed 0
# L == H
# fullSet, iter: 2 i:606, pairs changed 0
# L == H
# fullSet, iter: 2 i:607, pairs changed 0
# L == H
# fullSet, iter: 2 i:608, pairs changed 0
# L == H
# fullSet, iter: 2 i:609, pairs changed 0
# L == H
# fullSet, iter: 2 i:610, pairs changed 0
# L == H
# fullSet, iter: 2 i:611, pairs changed 0
# L == H
# fullSet, iter: 2 i:612, pairs changed 0
# L == H
# fullSet, iter: 2 i:613, pairs changed 0
# L == H
# fullSet, iter: 2 i:614, pairs changed 0
# L == H
# fullSet, iter: 2 i:615, pairs changed 0
# L == H
# fullSet, iter: 2 i:616, pairs changed 0
# L == H
# fullSet, iter: 2 i:617, pairs changed 0
# L == H
# fullSet, iter: 2 i:618, pairs changed 0
# L == H
# fullSet, iter: 2 i:619, pairs changed 0
# L == H
# fullSet, iter: 2 i:620, pairs changed 0
# L == H
# fullSet, iter: 2 i:621, pairs changed 0
# L == H
# fullSet, iter: 2 i:622, pairs changed 0
# L == H
# fullSet, iter: 2 i:623, pairs changed 0
# fullSet, iter: 2 i:624, pairs changed 0
# L == H
# fullSet, iter: 2 i:625, pairs changed 0
# L == H
# fullSet, iter: 2 i:626, pairs changed 0
# L == H
# fullSet, iter: 2 i:627, pairs changed 0
# L == H
# fullSet, iter: 2 i:628, pairs changed 0
# L == H
# fullSet, iter: 2 i:629, pairs changed 0
# L == H
# fullSet, iter: 2 i:630, pairs changed 0
# L == H
# fullSet, iter: 2 i:631, pairs changed 0
# L == H
# fullSet, iter: 2 i:632, pairs changed 0
# L == H
# fullSet, iter: 2 i:633, pairs changed 0
# L == H
# fullSet, iter: 2 i:634, pairs changed 0
# L == H
# fullSet, iter: 2 i:635, pairs changed 0
# L == H
# fullSet, iter: 2 i:636, pairs changed 0
# L == H
# fullSet, iter: 2 i:637, pairs changed 0
# L == H
# fullSet, iter: 2 i:638, pairs changed 0
# L == H
# fullSet, iter: 2 i:639, pairs changed 0
# fullSet, iter: 2 i:640, pairs changed 0
# L == H
# fullSet, iter: 2 i:641, pairs changed 0
# L == H
# fullSet, iter: 2 i:642, pairs changed 0
# L == H
# fullSet, iter: 2 i:643, pairs changed 0
# L == H
# fullSet, iter: 2 i:644, pairs changed 0
# L == H
# fullSet, iter: 2 i:645, pairs changed 0
# L == H
# fullSet, iter: 2 i:646, pairs changed 0
# L == H
# fullSet, iter: 2 i:647, pairs changed 0
# L == H
# fullSet, iter: 2 i:648, pairs changed 0
# L == H
# fullSet, iter: 2 i:649, pairs changed 0
# L == H
# fullSet, iter: 2 i:650, pairs changed 0
# L == H
# fullSet, iter: 2 i:651, pairs changed 0
# L == H
# fullSet, iter: 2 i:652, pairs changed 0
# L == H
# fullSet, iter: 2 i:653, pairs changed 0
# L == H
# fullSet, iter: 2 i:654, pairs changed 0
# L == H
# fullSet, iter: 2 i:655, pairs changed 0
# L == H
# fullSet, iter: 2 i:656, pairs changed 0
# L == H
# fullSet, iter: 2 i:657, pairs changed 0
# L == H
# fullSet, iter: 2 i:658, pairs changed 0
# L == H
# fullSet, iter: 2 i:659, pairs changed 0
# L == H
# fullSet, iter: 2 i:660, pairs changed 0
# L == H
# fullSet, iter: 2 i:661, pairs changed 0
# L == H
# fullSet, iter: 2 i:662, pairs changed 0
# L == H
# fullSet, iter: 2 i:663, pairs changed 0
# L == H
# fullSet, iter: 2 i:664, pairs changed 0
# L == H
# fullSet, iter: 2 i:665, pairs changed 0
# fullSet, iter: 2 i:666, pairs changed 0
# L == H
# fullSet, iter: 2 i:667, pairs changed 0
# L == H
# fullSet, iter: 2 i:668, pairs changed 0
# L == H
# fullSet, iter: 2 i:669, pairs changed 0
# L == H
# fullSet, iter: 2 i:670, pairs changed 0
# L == H
# fullSet, iter: 2 i:671, pairs changed 0
# L == H
# fullSet, iter: 2 i:672, pairs changed 0
# L == H
# fullSet, iter: 2 i:673, pairs changed 0
# L == H
# fullSet, iter: 2 i:674, pairs changed 0
# fullSet, iter: 2 i:675, pairs changed 0
# L == H
# fullSet, iter: 2 i:676, pairs changed 0
# L == H
# fullSet, iter: 2 i:677, pairs changed 0
# L == H
# fullSet, iter: 2 i:678, pairs changed 0
# L == H
# fullSet, iter: 2 i:679, pairs changed 0
# L == H
# fullSet, iter: 2 i:680, pairs changed 0
# L == H
# fullSet, iter: 2 i:681, pairs changed 0
# fullSet, iter: 2 i:682, pairs changed 0
# L == H
# fullSet, iter: 2 i:683, pairs changed 0
# L == H
# fullSet, iter: 2 i:684, pairs changed 0
# L == H
# fullSet, iter: 2 i:685, pairs changed 0
# L == H
# fullSet, iter: 2 i:686, pairs changed 0
# L == H
# fullSet, iter: 2 i:687, pairs changed 0
# L == H
# fullSet, iter: 2 i:688, pairs changed 0
# L == H
# fullSet, iter: 2 i:689, pairs changed 0
# fullSet, iter: 2 i:690, pairs changed 0
# L == H
# fullSet, iter: 2 i:691, pairs changed 0
# L == H
# fullSet, iter: 2 i:692, pairs changed 0
# L == H
# fullSet, iter: 2 i:693, pairs changed 0
# L == H
# fullSet, iter: 2 i:694, pairs changed 0
# L == H
# fullSet, iter: 2 i:695, pairs changed 0
# L == H
# fullSet, iter: 2 i:696, pairs changed 0
# L == H
# fullSet, iter: 2 i:697, pairs changed 0
# L == H
# fullSet, iter: 2 i:698, pairs changed 0
# L == H
# fullSet, iter: 2 i:699, pairs changed 0
# ACCURACY:0.934615

# %%
testRBF()
# Out:
# fullSet, iter: 0 i:0, pairs changed 1
# fullSet, iter: 0 i:1, pairs changed 2
# fullSet, iter: 0 i:2, pairs changed 3
# L == H
# fullSet, iter: 0 i:3, pairs changed 3
# L == H
# fullSet, iter: 0 i:4, pairs changed 3
# L == H
# fullSet, iter: 0 i:5, pairs changed 3
# L == H
# fullSet, iter: 0 i:6, pairs changed 3
# L == H
# fullSet, iter: 0 i:7, pairs changed 3
# L == H
# fullSet, iter: 0 i:8, pairs changed 3
# L == H
# fullSet, iter: 0 i:9, pairs changed 3
# L == H
# fullSet, iter: 0 i:10, pairs changed 3
# L == H
# fullSet, iter: 0 i:11, pairs changed 3
# L == H
# fullSet, iter: 0 i:12, pairs changed 3
# L == H
# fullSet, iter: 0 i:13, pairs changed 3
# L == H
# fullSet, iter: 0 i:14, pairs changed 3
# L == H
# fullSet, iter: 0 i:15, pairs changed 3
# L == H
# fullSet, iter: 0 i:16, pairs changed 3
# L == H
# fullSet, iter: 0 i:17, pairs changed 3
# L == H
# fullSet, iter: 0 i:18, pairs changed 3
# L == H
# fullSet, iter: 0 i:19, pairs changed 3
# L == H
# fullSet, iter: 0 i:20, pairs changed 3
# L == H
# fullSet, iter: 0 i:21, pairs changed 3
# L == H
# fullSet, iter: 0 i:22, pairs changed 3
# L == H
# fullSet, iter: 0 i:23, pairs changed 3
# L == H
# fullSet, iter: 0 i:24, pairs changed 3
# L == H
# fullSet, iter: 0 i:25, pairs changed 3
# L == H
# fullSet, iter: 0 i:26, pairs changed 3
# L == H
# fullSet, iter: 0 i:27, pairs changed 3
# L == H
# fullSet, iter: 0 i:28, pairs changed 3
# L == H
# fullSet, iter: 0 i:29, pairs changed 3
# L == H
# fullSet, iter: 0 i:30, pairs changed 3
# L == H
# fullSet, iter: 0 i:31, pairs changed 3
# L == H
# fullSet, iter: 0 i:32, pairs changed 3
# L == H
# fullSet, iter: 0 i:33, pairs changed 3
# L == H
# fullSet, iter: 0 i:34, pairs changed 3
# L == H
# fullSet, iter: 0 i:35, pairs changed 3
# L == H
# fullSet, iter: 0 i:36, pairs changed 3
# L == H
# fullSet, iter: 0 i:37, pairs changed 3
# L == H
# fullSet, iter: 0 i:38, pairs changed 3
# L == H
# fullSet, iter: 0 i:39, pairs changed 3
# L == H
# fullSet, iter: 0 i:40, pairs changed 3
# L == H
# fullSet, iter: 0 i:41, pairs changed 3
# L == H
# fullSet, iter: 0 i:42, pairs changed 3
# L == H
# fullSet, iter: 0 i:43, pairs changed 3
# L == H
# fullSet, iter: 0 i:44, pairs changed 3
# L == H
# fullSet, iter: 0 i:45, pairs changed 3
# L == H
# fullSet, iter: 0 i:46, pairs changed 3
# L == H
# fullSet, iter: 0 i:47, pairs changed 3
# L == H
# fullSet, iter: 0 i:48, pairs changed 3
# L == H
# fullSet, iter: 0 i:49, pairs changed 3
# L == H
# fullSet, iter: 0 i:50, pairs changed 3
# L == H
# fullSet, iter: 0 i:51, pairs changed 3
# L == H
# fullSet, iter: 0 i:52, pairs changed 3
# L == H
# fullSet, iter: 0 i:53, pairs changed 3
# L == H
# fullSet, iter: 0 i:54, pairs changed 3
# L == H
# fullSet, iter: 0 i:55, pairs changed 3
# L == H
# fullSet, iter: 0 i:56, pairs changed 3
# L == H
# fullSet, iter: 0 i:57, pairs changed 3
# L == H
# fullSet, iter: 0 i:58, pairs changed 3
# L == H
# fullSet, iter: 0 i:59, pairs changed 3
# L == H
# fullSet, iter: 0 i:60, pairs changed 3
# L == H
# fullSet, iter: 0 i:61, pairs changed 3
# L == H
# fullSet, iter: 0 i:62, pairs changed 3
# L == H
# fullSet, iter: 0 i:63, pairs changed 3
# L == H
# fullSet, iter: 0 i:64, pairs changed 3
# L == H
# fullSet, iter: 0 i:65, pairs changed 3
# L == H
# fullSet, iter: 0 i:66, pairs changed 3
# L == H
# fullSet, iter: 0 i:67, pairs changed 3
# L == H
# fullSet, iter: 0 i:68, pairs changed 3
# L == H
# fullSet, iter: 0 i:69, pairs changed 3
# L == H
# fullSet, iter: 0 i:70, pairs changed 3
# L == H
# fullSet, iter: 0 i:71, pairs changed 3
# L == H
# fullSet, iter: 0 i:72, pairs changed 3
# L == H
# fullSet, iter: 0 i:73, pairs changed 3
# L == H
# fullSet, iter: 0 i:74, pairs changed 3
# L == H
# fullSet, iter: 0 i:75, pairs changed 3
# L == H
# fullSet, iter: 0 i:76, pairs changed 3
# L == H
# fullSet, iter: 0 i:77, pairs changed 3
# L == H
# fullSet, iter: 0 i:78, pairs changed 3
# L == H
# fullSet, iter: 0 i:79, pairs changed 3
# L == H
# fullSet, iter: 0 i:80, pairs changed 3
# L == H
# fullSet, iter: 0 i:81, pairs changed 3
# L == H
# fullSet, iter: 0 i:82, pairs changed 3
# L == H
# fullSet, iter: 0 i:83, pairs changed 3
# L == H
# fullSet, iter: 0 i:84, pairs changed 3
# L == H
# fullSet, iter: 0 i:85, pairs changed 3
# L == H
# fullSet, iter: 0 i:86, pairs changed 3
# L == H
# fullSet, iter: 0 i:87, pairs changed 3
# L == H
# fullSet, iter: 0 i:88, pairs changed 3
# L == H
# fullSet, iter: 0 i:89, pairs changed 3
# L == H
# fullSet, iter: 0 i:90, pairs changed 3
# L == H
# fullSet, iter: 0 i:91, pairs changed 3
# L == H
# fullSet, iter: 0 i:92, pairs changed 3
# L == H
# fullSet, iter: 0 i:93, pairs changed 3
# L == H
# fullSet, iter: 0 i:94, pairs changed 3
# L == H
# fullSet, iter: 0 i:95, pairs changed 3
# L == H
# fullSet, iter: 0 i:96, pairs changed 3
# L == H
# fullSet, iter: 0 i:97, pairs changed 3
# L == H
# fullSet, iter: 0 i:98, pairs changed 3
# L == H
# fullSet, iter: 0 i:99, pairs changed 3
# L == H
# fullSet, iter: 0 i:100, pairs changed 3
# L == H
# fullSet, iter: 0 i:101, pairs changed 3
# L == H
# fullSet, iter: 0 i:102, pairs changed 3
# L == H
# fullSet, iter: 0 i:103, pairs changed 3
# L == H
# fullSet, iter: 0 i:104, pairs changed 3
# L == H
# fullSet, iter: 0 i:105, pairs changed 3
# L == H
# fullSet, iter: 0 i:106, pairs changed 3
# L == H
# fullSet, iter: 0 i:107, pairs changed 3
# L == H
# fullSet, iter: 0 i:108, pairs changed 3
# L == H
# fullSet, iter: 0 i:109, pairs changed 3
# L == H
# fullSet, iter: 0 i:110, pairs changed 3
# L == H
# fullSet, iter: 0 i:111, pairs changed 3
# L == H
# fullSet, iter: 0 i:112, pairs changed 3
# L == H
# fullSet, iter: 0 i:113, pairs changed 3
# L == H
# fullSet, iter: 0 i:114, pairs changed 3
# L == H
# fullSet, iter: 0 i:115, pairs changed 3
# L == H
# fullSet, iter: 0 i:116, pairs changed 3
# L == H
# fullSet, iter: 0 i:117, pairs changed 3
# L == H
# fullSet, iter: 0 i:118, pairs changed 3
# L == H
# fullSet, iter: 0 i:119, pairs changed 3
# L == H
# fullSet, iter: 0 i:120, pairs changed 3
# L == H
# fullSet, iter: 0 i:121, pairs changed 3
# L == H
# fullSet, iter: 0 i:122, pairs changed 3
# L == H
# fullSet, iter: 0 i:123, pairs changed 3
# L == H
# fullSet, iter: 0 i:124, pairs changed 3
# L == H
# fullSet, iter: 0 i:125, pairs changed 3
# L == H
# fullSet, iter: 0 i:126, pairs changed 3
# L == H
# fullSet, iter: 0 i:127, pairs changed 3
# L == H
# fullSet, iter: 0 i:128, pairs changed 3
# L == H
# fullSet, iter: 0 i:129, pairs changed 3
# L == H
# fullSet, iter: 0 i:130, pairs changed 3
# L == H
# fullSet, iter: 0 i:131, pairs changed 3
# L == H
# fullSet, iter: 0 i:132, pairs changed 3
# L == H
# fullSet, iter: 0 i:133, pairs changed 3
# L == H
# fullSet, iter: 0 i:134, pairs changed 3
# L == H
# fullSet, iter: 0 i:135, pairs changed 3
# L == H
# fullSet, iter: 0 i:136, pairs changed 3
# L == H
# fullSet, iter: 0 i:137, pairs changed 3
# L == H
# fullSet, iter: 0 i:138, pairs changed 3
# L == H
# fullSet, iter: 0 i:139, pairs changed 3
# L == H
# fullSet, iter: 0 i:140, pairs changed 3
# L == H
# fullSet, iter: 0 i:141, pairs changed 3
# L == H
# fullSet, iter: 0 i:142, pairs changed 3
# L == H
# fullSet, iter: 0 i:143, pairs changed 3
# L == H
# fullSet, iter: 0 i:144, pairs changed 3
# L == H
# fullSet, iter: 0 i:145, pairs changed 3
# L == H
# fullSet, iter: 0 i:146, pairs changed 3
# L == H
# fullSet, iter: 0 i:147, pairs changed 3
# L == H
# fullSet, iter: 0 i:148, pairs changed 3
# L == H
# fullSet, iter: 0 i:149, pairs changed 3
# L == H
# fullSet, iter: 0 i:150, pairs changed 3
# L == H
# fullSet, iter: 0 i:151, pairs changed 3
# L == H
# fullSet, iter: 0 i:152, pairs changed 3
# L == H
# fullSet, iter: 0 i:153, pairs changed 3
# L == H
# fullSet, iter: 0 i:154, pairs changed 3
# L == H
# fullSet, iter: 0 i:155, pairs changed 3
# L == H
# fullSet, iter: 0 i:156, pairs changed 3
# L == H
# fullSet, iter: 0 i:157, pairs changed 3
# L == H
# fullSet, iter: 0 i:158, pairs changed 3
# L == H
# fullSet, iter: 0 i:159, pairs changed 3
# L == H
# fullSet, iter: 0 i:160, pairs changed 3
# L == H
# fullSet, iter: 0 i:161, pairs changed 3
# L == H
# fullSet, iter: 0 i:162, pairs changed 3
# L == H
# fullSet, iter: 0 i:163, pairs changed 3
# L == H
# fullSet, iter: 0 i:164, pairs changed 3
# L == H
# fullSet, iter: 0 i:165, pairs changed 3
# L == H
# fullSet, iter: 0 i:166, pairs changed 3
# L == H
# fullSet, iter: 0 i:167, pairs changed 3
# L == H
# fullSet, iter: 0 i:168, pairs changed 3
# L == H
# fullSet, iter: 0 i:169, pairs changed 3
# L == H
# fullSet, iter: 0 i:170, pairs changed 3
# L == H
# fullSet, iter: 0 i:171, pairs changed 3
# L == H
# fullSet, iter: 0 i:172, pairs changed 3
# L == H
# fullSet, iter: 0 i:173, pairs changed 3
# L == H
# fullSet, iter: 0 i:174, pairs changed 3
# L == H
# fullSet, iter: 0 i:175, pairs changed 3
# L == H
# fullSet, iter: 0 i:176, pairs changed 3
# L == H
# fullSet, iter: 0 i:177, pairs changed 3
# L == H
# fullSet, iter: 0 i:178, pairs changed 3
# L == H
# fullSet, iter: 0 i:179, pairs changed 3
# L == H
# fullSet, iter: 0 i:180, pairs changed 3
# L == H
# fullSet, iter: 0 i:181, pairs changed 3
# L == H
# fullSet, iter: 0 i:182, pairs changed 3
# L == H
# fullSet, iter: 0 i:183, pairs changed 3
# L == H
# fullSet, iter: 0 i:184, pairs changed 3
# L == H
# fullSet, iter: 0 i:185, pairs changed 3
# L == H
# fullSet, iter: 0 i:186, pairs changed 3
# L == H
# fullSet, iter: 0 i:187, pairs changed 3
# L == H
# fullSet, iter: 0 i:188, pairs changed 3
# L == H
# fullSet, iter: 0 i:189, pairs changed 3
# L == H
# fullSet, iter: 0 i:190, pairs changed 3
# L == H
# fullSet, iter: 0 i:191, pairs changed 3
# L == H
# fullSet, iter: 0 i:192, pairs changed 3
# fullSet, iter: 0 i:193, pairs changed 3
# fullSet, iter: 0 i:194, pairs changed 3
# fullSet, iter: 0 i:195, pairs changed 4
# fullSet, iter: 0 i:196, pairs changed 5
# fullSet, iter: 0 i:197, pairs changed 6
# fullSet, iter: 0 i:198, pairs changed 7
# fullSet, iter: 0 i:199, pairs changed 8
# L == H
# fullSet, iter: 0 i:200, pairs changed 8
# L == H
# fullSet, iter: 0 i:201, pairs changed 8
# L == H
# fullSet, iter: 0 i:202, pairs changed 8
# L == H
# fullSet, iter: 0 i:203, pairs changed 8
# L == H
# fullSet, iter: 0 i:204, pairs changed 8
# L == H
# fullSet, iter: 0 i:205, pairs changed 8
# L == H
# fullSet, iter: 0 i:206, pairs changed 8
# L == H
# fullSet, iter: 0 i:207, pairs changed 8
# L == H
# fullSet, iter: 0 i:208, pairs changed 8
# L == H
# fullSet, iter: 0 i:209, pairs changed 8
# L == H
# fullSet, iter: 0 i:210, pairs changed 8
# L == H
# fullSet, iter: 0 i:211, pairs changed 8
# L == H
# fullSet, iter: 0 i:212, pairs changed 8
# L == H
# fullSet, iter: 0 i:213, pairs changed 8
# L == H
# fullSet, iter: 0 i:214, pairs changed 8
# L == H
# fullSet, iter: 0 i:215, pairs changed 8
# L == H
# fullSet, iter: 0 i:216, pairs changed 8
# L == H
# fullSet, iter: 0 i:217, pairs changed 8
# L == H
# fullSet, iter: 0 i:218, pairs changed 8
# L == H
# fullSet, iter: 0 i:219, pairs changed 8
# L == H
# fullSet, iter: 0 i:220, pairs changed 8
# L == H
# fullSet, iter: 0 i:221, pairs changed 8
# L == H
# fullSet, iter: 0 i:222, pairs changed 8
# L == H
# fullSet, iter: 0 i:223, pairs changed 8
# L == H
# fullSet, iter: 0 i:224, pairs changed 8
# L == H
# fullSet, iter: 0 i:225, pairs changed 8
# L == H
# fullSet, iter: 0 i:226, pairs changed 8
# L == H
# fullSet, iter: 0 i:227, pairs changed 8
# L == H
# fullSet, iter: 0 i:228, pairs changed 8
# L == H
# fullSet, iter: 0 i:229, pairs changed 8
# L == H
# fullSet, iter: 0 i:230, pairs changed 8
# L == H
# fullSet, iter: 0 i:231, pairs changed 8
# L == H
# fullSet, iter: 0 i:232, pairs changed 8
# L == H
# fullSet, iter: 0 i:233, pairs changed 8
# L == H
# fullSet, iter: 0 i:234, pairs changed 8
# L == H
# fullSet, iter: 0 i:235, pairs changed 8
# L == H
# fullSet, iter: 0 i:236, pairs changed 8
# L == H
# fullSet, iter: 0 i:237, pairs changed 8
# L == H
# fullSet, iter: 0 i:238, pairs changed 8
# L == H
# fullSet, iter: 0 i:239, pairs changed 8
# L == H
# fullSet, iter: 0 i:240, pairs changed 8
# L == H
# fullSet, iter: 0 i:241, pairs changed 8
# L == H
# fullSet, iter: 0 i:242, pairs changed 8
# L == H
# fullSet, iter: 0 i:243, pairs changed 8
# L == H
# fullSet, iter: 0 i:244, pairs changed 8
# L == H
# fullSet, iter: 0 i:245, pairs changed 8
# L == H
# fullSet, iter: 0 i:246, pairs changed 8
# L == H
# fullSet, iter: 0 i:247, pairs changed 8
# L == H
# fullSet, iter: 0 i:248, pairs changed 8
# L == H
# fullSet, iter: 0 i:249, pairs changed 8
# L == H
# fullSet, iter: 0 i:250, pairs changed 8
# L == H
# fullSet, iter: 0 i:251, pairs changed 8
# L == H
# fullSet, iter: 0 i:252, pairs changed 8
# L == H
# fullSet, iter: 0 i:253, pairs changed 8
# L == H
# fullSet, iter: 0 i:254, pairs changed 8
# L == H
# fullSet, iter: 0 i:255, pairs changed 8
# L == H
# fullSet, iter: 0 i:256, pairs changed 8
# L == H
# fullSet, iter: 0 i:257, pairs changed 8
# L == H
# fullSet, iter: 0 i:258, pairs changed 8
# L == H
# fullSet, iter: 0 i:259, pairs changed 8
# L == H
# fullSet, iter: 0 i:260, pairs changed 8
# L == H
# fullSet, iter: 0 i:261, pairs changed 8
# L == H
# fullSet, iter: 0 i:262, pairs changed 8
# L == H
# fullSet, iter: 0 i:263, pairs changed 8
# L == H
# fullSet, iter: 0 i:264, pairs changed 8
# L == H
# fullSet, iter: 0 i:265, pairs changed 8
# L == H
# fullSet, iter: 0 i:266, pairs changed 8
# L == H
# fullSet, iter: 0 i:267, pairs changed 8
# L == H
# fullSet, iter: 0 i:268, pairs changed 8
# L == H
# fullSet, iter: 0 i:269, pairs changed 8
# L == H
# fullSet, iter: 0 i:270, pairs changed 8
# L == H
# fullSet, iter: 0 i:271, pairs changed 8
# L == H
# fullSet, iter: 0 i:272, pairs changed 8
# L == H
# fullSet, iter: 0 i:273, pairs changed 8
# L == H
# fullSet, iter: 0 i:274, pairs changed 8
# L == H
# fullSet, iter: 0 i:275, pairs changed 8
# L == H
# fullSet, iter: 0 i:276, pairs changed 8
# L == H
# fullSet, iter: 0 i:277, pairs changed 8
# L == H
# fullSet, iter: 0 i:278, pairs changed 8
# L == H
# fullSet, iter: 0 i:279, pairs changed 8
# L == H
# fullSet, iter: 0 i:280, pairs changed 8
# L == H
# fullSet, iter: 0 i:281, pairs changed 8
# L == H
# fullSet, iter: 0 i:282, pairs changed 8
# L == H
# fullSet, iter: 0 i:283, pairs changed 8
# L == H
# fullSet, iter: 0 i:284, pairs changed 8
# L == H
# fullSet, iter: 0 i:285, pairs changed 8
# L == H
# fullSet, iter: 0 i:286, pairs changed 8
# L == H
# fullSet, iter: 0 i:287, pairs changed 8
# L == H
# fullSet, iter: 0 i:288, pairs changed 8
# L == H
# fullSet, iter: 0 i:289, pairs changed 8
# L == H
# fullSet, iter: 0 i:290, pairs changed 8
# L == H
# fullSet, iter: 0 i:291, pairs changed 8
# L == H
# fullSet, iter: 0 i:292, pairs changed 8
# L == H
# fullSet, iter: 0 i:293, pairs changed 8
# L == H
# fullSet, iter: 0 i:294, pairs changed 8
# L == H
# fullSet, iter: 0 i:295, pairs changed 8
# L == H
# fullSet, iter: 0 i:296, pairs changed 8
# L == H
# fullSet, iter: 0 i:297, pairs changed 8
# L == H
# fullSet, iter: 0 i:298, pairs changed 8
# L == H
# fullSet, iter: 0 i:299, pairs changed 8
# L == H
# fullSet, iter: 0 i:300, pairs changed 8
# L == H
# fullSet, iter: 0 i:301, pairs changed 8
# L == H
# fullSet, iter: 0 i:302, pairs changed 8
# L == H
# fullSet, iter: 0 i:303, pairs changed 8
# L == H
# fullSet, iter: 0 i:304, pairs changed 8
# L == H
# fullSet, iter: 0 i:305, pairs changed 8
# L == H
# fullSet, iter: 0 i:306, pairs changed 8
# L == H
# fullSet, iter: 0 i:307, pairs changed 8
# L == H
# fullSet, iter: 0 i:308, pairs changed 8
# L == H
# fullSet, iter: 0 i:309, pairs changed 8
# L == H
# fullSet, iter: 0 i:310, pairs changed 8
# L == H
# fullSet, iter: 0 i:311, pairs changed 8
# L == H
# fullSet, iter: 0 i:312, pairs changed 8
# L == H
# fullSet, iter: 0 i:313, pairs changed 8
# L == H
# fullSet, iter: 0 i:314, pairs changed 8
# L == H
# fullSet, iter: 0 i:315, pairs changed 8
# L == H
# fullSet, iter: 0 i:316, pairs changed 8
# L == H
# fullSet, iter: 0 i:317, pairs changed 8
# L == H
# fullSet, iter: 0 i:318, pairs changed 8
# L == H
# fullSet, iter: 0 i:319, pairs changed 8
# L == H
# fullSet, iter: 0 i:320, pairs changed 8
# L == H
# fullSet, iter: 0 i:321, pairs changed 8
# L == H
# fullSet, iter: 0 i:322, pairs changed 8
# L == H
# fullSet, iter: 0 i:323, pairs changed 8
# fullSet, iter: 0 i:324, pairs changed 9
# fullSet, iter: 0 i:325, pairs changed 10
# fullSet, iter: 0 i:326, pairs changed 11
# L == H
# fullSet, iter: 0 i:327, pairs changed 11
# L == H
# fullSet, iter: 0 i:328, pairs changed 11
# L == H
# fullSet, iter: 0 i:329, pairs changed 11
# L == H
# fullSet, iter: 0 i:330, pairs changed 11
# L == H
# fullSet, iter: 0 i:331, pairs changed 11
# L == H
# fullSet, iter: 0 i:332, pairs changed 11
# L == H
# fullSet, iter: 0 i:333, pairs changed 11
# L == H
# fullSet, iter: 0 i:334, pairs changed 11
# L == H
# fullSet, iter: 0 i:335, pairs changed 11
# L == H
# fullSet, iter: 0 i:336, pairs changed 11
# L == H
# fullSet, iter: 0 i:337, pairs changed 11
# L == H
# fullSet, iter: 0 i:338, pairs changed 11
# L == H
# fullSet, iter: 0 i:339, pairs changed 11
# fullSet, iter: 0 i:340, pairs changed 11
# L == H
# fullSet, iter: 0 i:341, pairs changed 11
# L == H
# fullSet, iter: 0 i:342, pairs changed 11
# L == H
# fullSet, iter: 0 i:343, pairs changed 11
# L == H
# fullSet, iter: 0 i:344, pairs changed 11
# L == H
# fullSet, iter: 0 i:345, pairs changed 11
# L == H
# fullSet, iter: 0 i:346, pairs changed 11
# L == H
# fullSet, iter: 0 i:347, pairs changed 11
# L == H
# fullSet, iter: 0 i:348, pairs changed 11
# L == H
# fullSet, iter: 0 i:349, pairs changed 11
# L == H
# fullSet, iter: 0 i:350, pairs changed 11
# L == H
# fullSet, iter: 0 i:351, pairs changed 11
# L == H
# fullSet, iter: 0 i:352, pairs changed 11
# L == H
# fullSet, iter: 0 i:353, pairs changed 11
# L == H
# fullSet, iter: 0 i:354, pairs changed 11
# L == H
# fullSet, iter: 0 i:355, pairs changed 11
# L == H
# fullSet, iter: 0 i:356, pairs changed 11
# L == H
# fullSet, iter: 0 i:357, pairs changed 11
# L == H
# fullSet, iter: 0 i:358, pairs changed 11
# L == H
# fullSet, iter: 0 i:359, pairs changed 11
# L == H
# fullSet, iter: 0 i:360, pairs changed 11
# L == H
# fullSet, iter: 0 i:361, pairs changed 11
# L == H
# fullSet, iter: 0 i:362, pairs changed 11
# L == H
# fullSet, iter: 0 i:363, pairs changed 11
# L == H
# fullSet, iter: 0 i:364, pairs changed 11
# L == H
# fullSet, iter: 0 i:365, pairs changed 11
# L == H
# fullSet, iter: 0 i:366, pairs changed 11
# L == H
# fullSet, iter: 0 i:367, pairs changed 11
# fullSet, iter: 0 i:368, pairs changed 11
# L == H
# fullSet, iter: 0 i:369, pairs changed 11
# L == H
# fullSet, iter: 0 i:370, pairs changed 11
# L == H
# fullSet, iter: 0 i:371, pairs changed 11
# L == H
# fullSet, iter: 0 i:372, pairs changed 11
# L == H
# fullSet, iter: 0 i:373, pairs changed 11
# L == H
# fullSet, iter: 0 i:374, pairs changed 11
# L == H
# fullSet, iter: 0 i:375, pairs changed 11
# L == H
# fullSet, iter: 0 i:376, pairs changed 11
# fullSet, iter: 0 i:377, pairs changed 11
# fullSet, iter: 0 i:378, pairs changed 12
# fullSet, iter: 0 i:379, pairs changed 13
# L == H
# fullSet, iter: 0 i:380, pairs changed 13
# L == H
# fullSet, iter: 0 i:381, pairs changed 13
# L == H
# fullSet, iter: 0 i:382, pairs changed 13
# L == H
# fullSet, iter: 0 i:383, pairs changed 13
# L == H
# fullSet, iter: 0 i:384, pairs changed 13
# L == H
# fullSet, iter: 0 i:385, pairs changed 13
# L == H
# fullSet, iter: 0 i:386, pairs changed 13
# L == H
# fullSet, iter: 0 i:387, pairs changed 13
# L == H
# fullSet, iter: 0 i:388, pairs changed 13
# L == H
# fullSet, iter: 0 i:389, pairs changed 13
# L == H
# fullSet, iter: 0 i:390, pairs changed 13
# L == H
# fullSet, iter: 0 i:391, pairs changed 13
# L == H
# fullSet, iter: 0 i:392, pairs changed 13
# L == H
# fullSet, iter: 0 i:393, pairs changed 13
# L == H
# fullSet, iter: 0 i:394, pairs changed 13
# L == H
# fullSet, iter: 0 i:395, pairs changed 13
# L == H
# fullSet, iter: 0 i:396, pairs changed 13
# L == H
# fullSet, iter: 0 i:397, pairs changed 13
# L == H
# fullSet, iter: 0 i:398, pairs changed 13
# L == H
# fullSet, iter: 0 i:399, pairs changed 13
# L == H
# fullSet, iter: 0 i:400, pairs changed 13
# L == H
# fullSet, iter: 0 i:401, pairs changed 13
# L == H
# fullSet, iter: 0 i:402, pairs changed 13
# L == H
# fullSet, iter: 0 i:403, pairs changed 13
# L == H
# fullSet, iter: 0 i:404, pairs changed 13
# L == H
# fullSet, iter: 0 i:405, pairs changed 13
# fullSet, iter: 0 i:406, pairs changed 14
# L == H
# fullSet, iter: 0 i:407, pairs changed 14
# L == H
# fullSet, iter: 0 i:408, pairs changed 14
# L == H
# fullSet, iter: 0 i:409, pairs changed 14
# L == H
# fullSet, iter: 0 i:410, pairs changed 14
# L == H
# fullSet, iter: 0 i:411, pairs changed 14
# L == H
# fullSet, iter: 0 i:412, pairs changed 14
# L == H
# fullSet, iter: 0 i:413, pairs changed 14
# L == H
# fullSet, iter: 0 i:414, pairs changed 14
# L == H
# fullSet, iter: 0 i:415, pairs changed 14
# L == H
# fullSet, iter: 0 i:416, pairs changed 14
# L == H
# fullSet, iter: 0 i:417, pairs changed 14
# L == H
# fullSet, iter: 0 i:418, pairs changed 14
# L == H
# fullSet, iter: 0 i:419, pairs changed 14
# L == H
# fullSet, iter: 0 i:420, pairs changed 14
# L == H
# fullSet, iter: 0 i:421, pairs changed 14
# L == H
# fullSet, iter: 0 i:422, pairs changed 14
# L == H
# fullSet, iter: 0 i:423, pairs changed 14
# L == H
# fullSet, iter: 0 i:424, pairs changed 14
# L == H
# fullSet, iter: 0 i:425, pairs changed 14
# L == H
# fullSet, iter: 0 i:426, pairs changed 14
# L == H
# fullSet, iter: 0 i:427, pairs changed 14
# L == H
# fullSet, iter: 0 i:428, pairs changed 14
# L == H
# fullSet, iter: 0 i:429, pairs changed 14
# L == H
# fullSet, iter: 0 i:430, pairs changed 14
# L == H
# fullSet, iter: 0 i:431, pairs changed 14
# L == H
# fullSet, iter: 0 i:432, pairs changed 14
# L == H
# fullSet, iter: 0 i:433, pairs changed 14
# L == H
# fullSet, iter: 0 i:434, pairs changed 14
# L == H
# fullSet, iter: 0 i:435, pairs changed 14
# L == H
# fullSet, iter: 0 i:436, pairs changed 14
# L == H
# fullSet, iter: 0 i:437, pairs changed 14
# L == H
# fullSet, iter: 0 i:438, pairs changed 14
# L == H
# fullSet, iter: 0 i:439, pairs changed 14
# L == H
# fullSet, iter: 0 i:440, pairs changed 14
# L == H
# fullSet, iter: 0 i:441, pairs changed 14
# L == H
# fullSet, iter: 0 i:442, pairs changed 14
# L == H
# fullSet, iter: 0 i:443, pairs changed 14
# L == H
# fullSet, iter: 0 i:444, pairs changed 14
# L == H
# fullSet, iter: 0 i:445, pairs changed 14
# L == H
# fullSet, iter: 0 i:446, pairs changed 14
# L == H
# fullSet, iter: 0 i:447, pairs changed 14
# fullSet, iter: 0 i:448, pairs changed 14
# L == H
# fullSet, iter: 0 i:449, pairs changed 14
# L == H
# fullSet, iter: 0 i:450, pairs changed 14
# L == H
# fullSet, iter: 0 i:451, pairs changed 14
# L == H
# fullSet, iter: 0 i:452, pairs changed 14
# fullSet, iter: 0 i:453, pairs changed 15
# fullSet, iter: 0 i:454, pairs changed 16
# fullSet, iter: 0 i:455, pairs changed 17
# fullSet, iter: 0 i:456, pairs changed 17
# fullSet, iter: 0 i:457, pairs changed 17
# fullSet, iter: 0 i:458, pairs changed 17
# fullSet, iter: 0 i:459, pairs changed 17
# fullSet, iter: 0 i:460, pairs changed 17
# fullSet, iter: 0 i:461, pairs changed 17
# fullSet, iter: 0 i:462, pairs changed 17
# fullSet, iter: 0 i:463, pairs changed 17
# fullSet, iter: 0 i:464, pairs changed 17
# fullSet, iter: 0 i:465, pairs changed 17
# fullSet, iter: 0 i:466, pairs changed 17
# fullSet, iter: 0 i:467, pairs changed 17
# L == H
# fullSet, iter: 0 i:468, pairs changed 17
# L == H
# fullSet, iter: 0 i:469, pairs changed 17
# L == H
# fullSet, iter: 0 i:470, pairs changed 17
# fullSet, iter: 0 i:471, pairs changed 17
# fullSet, iter: 0 i:472, pairs changed 17
# fullSet, iter: 0 i:473, pairs changed 17
# fullSet, iter: 0 i:474, pairs changed 17
# fullSet, iter: 0 i:475, pairs changed 17
# fullSet, iter: 0 i:476, pairs changed 17
# L == H
# fullSet, iter: 0 i:477, pairs changed 17
# L == H
# fullSet, iter: 0 i:478, pairs changed 17
# L == H
# fullSet, iter: 0 i:479, pairs changed 17
# L == H
# fullSet, iter: 0 i:480, pairs changed 17
# L == H
# fullSet, iter: 0 i:481, pairs changed 17
# L == H
# fullSet, iter: 0 i:482, pairs changed 17
# L == H
# fullSet, iter: 0 i:483, pairs changed 17
# L == H
# fullSet, iter: 0 i:484, pairs changed 17
# L == H
# fullSet, iter: 0 i:485, pairs changed 17
# L == H
# fullSet, iter: 0 i:486, pairs changed 17
# L == H
# fullSet, iter: 0 i:487, pairs changed 17
# L == H
# fullSet, iter: 0 i:488, pairs changed 17
# L == H
# fullSet, iter: 0 i:489, pairs changed 17
# L == H
# fullSet, iter: 0 i:490, pairs changed 17
# L == H
# fullSet, iter: 0 i:491, pairs changed 17
# L == H
# fullSet, iter: 0 i:492, pairs changed 17
# L == H
# fullSet, iter: 0 i:493, pairs changed 17
# L == H
# fullSet, iter: 0 i:494, pairs changed 17
# L == H
# fullSet, iter: 0 i:495, pairs changed 17
# L == H
# fullSet, iter: 0 i:496, pairs changed 17
# L == H
# fullSet, iter: 0 i:497, pairs changed 17
# L == H
# fullSet, iter: 0 i:498, pairs changed 17
# L == H
# fullSet, iter: 0 i:499, pairs changed 17
# L == H
# fullSet, iter: 0 i:500, pairs changed 17
# L == H
# fullSet, iter: 0 i:501, pairs changed 17
# L == H
# fullSet, iter: 0 i:502, pairs changed 17
# L == H
# fullSet, iter: 0 i:503, pairs changed 17
# L == H
# fullSet, iter: 0 i:504, pairs changed 17
# L == H
# fullSet, iter: 0 i:505, pairs changed 17
# L == H
# fullSet, iter: 0 i:506, pairs changed 17
# L == H
# fullSet, iter: 0 i:507, pairs changed 17
# L == H
# fullSet, iter: 0 i:508, pairs changed 17
# L == H
# fullSet, iter: 0 i:509, pairs changed 17
# L == H
# fullSet, iter: 0 i:510, pairs changed 17
# L == H
# fullSet, iter: 0 i:511, pairs changed 17
# L == H
# fullSet, iter: 0 i:512, pairs changed 17
# L == H
# fullSet, iter: 0 i:513, pairs changed 17
# L == H
# fullSet, iter: 0 i:514, pairs changed 17
# L == H
# fullSet, iter: 0 i:515, pairs changed 17
# L == H
# fullSet, iter: 0 i:516, pairs changed 17
# L == H
# fullSet, iter: 0 i:517, pairs changed 17
# L == H
# fullSet, iter: 0 i:518, pairs changed 17
# L == H
# fullSet, iter: 0 i:519, pairs changed 17
# fullSet, iter: 0 i:520, pairs changed 17
# L == H
# fullSet, iter: 0 i:521, pairs changed 17
# L == H
# fullSet, iter: 0 i:522, pairs changed 17
# L == H
# fullSet, iter: 0 i:523, pairs changed 17
# L == H
# fullSet, iter: 0 i:524, pairs changed 17
# L == H
# fullSet, iter: 0 i:525, pairs changed 17
# L == H
# fullSet, iter: 0 i:526, pairs changed 17
# L == H
# fullSet, iter: 0 i:527, pairs changed 17
# L == H
# fullSet, iter: 0 i:528, pairs changed 17
# L == H
# fullSet, iter: 0 i:529, pairs changed 17
# L == H
# fullSet, iter: 0 i:530, pairs changed 17
# L == H
# fullSet, iter: 0 i:531, pairs changed 17
# L == H
# fullSet, iter: 0 i:532, pairs changed 17
# L == H
# fullSet, iter: 0 i:533, pairs changed 17
# L == H
# fullSet, iter: 0 i:534, pairs changed 17
# L == H
# fullSet, iter: 0 i:535, pairs changed 17
# L == H
# fullSet, iter: 0 i:536, pairs changed 17
# L == H
# fullSet, iter: 0 i:537, pairs changed 17
# fullSet, iter: 0 i:538, pairs changed 17
# L == H
# fullSet, iter: 0 i:539, pairs changed 17
# L == H
# fullSet, iter: 0 i:540, pairs changed 17
# L == H
# fullSet, iter: 0 i:541, pairs changed 17
# L == H
# fullSet, iter: 0 i:542, pairs changed 17
# L == H
# fullSet, iter: 0 i:543, pairs changed 17
# L == H
# fullSet, iter: 0 i:544, pairs changed 17
# L == H
# fullSet, iter: 0 i:545, pairs changed 17
# L == H
# fullSet, iter: 0 i:546, pairs changed 17
# L == H
# fullSet, iter: 0 i:547, pairs changed 17
# L == H
# fullSet, iter: 0 i:548, pairs changed 17
# L == H
# fullSet, iter: 0 i:549, pairs changed 17
# L == H
# fullSet, iter: 0 i:550, pairs changed 17
# L == H
# fullSet, iter: 0 i:551, pairs changed 17
# L == H
# fullSet, iter: 0 i:552, pairs changed 17
# L == H
# fullSet, iter: 0 i:553, pairs changed 17
# L == H
# fullSet, iter: 0 i:554, pairs changed 17
# L == H
# fullSet, iter: 0 i:555, pairs changed 17
# L == H
# fullSet, iter: 0 i:556, pairs changed 17
# L == H
# fullSet, iter: 0 i:557, pairs changed 17
# L == H
# fullSet, iter: 0 i:558, pairs changed 17
# L == H
# fullSet, iter: 0 i:559, pairs changed 17
# L == H
# fullSet, iter: 0 i:560, pairs changed 17
# L == H
# fullSet, iter: 0 i:561, pairs changed 17
# L == H
# fullSet, iter: 0 i:562, pairs changed 17
# fullSet, iter: 0 i:563, pairs changed 17
# L == H
# fullSet, iter: 0 i:564, pairs changed 17
# L == H
# fullSet, iter: 0 i:565, pairs changed 17
# L == H
# fullSet, iter: 0 i:566, pairs changed 17
# L == H
# fullSet, iter: 0 i:567, pairs changed 17
# L == H
# fullSet, iter: 0 i:568, pairs changed 17
# L == H
# fullSet, iter: 0 i:569, pairs changed 17
# L == H
# fullSet, iter: 0 i:570, pairs changed 17
# L == H
# fullSet, iter: 0 i:571, pairs changed 17
# L == H
# fullSet, iter: 0 i:572, pairs changed 17
# fullSet, iter: 0 i:573, pairs changed 17
# fullSet, iter: 0 i:574, pairs changed 17
# fullSet, iter: 0 i:575, pairs changed 17
# L == H
# fullSet, iter: 0 i:576, pairs changed 17
# L == H
# fullSet, iter: 0 i:577, pairs changed 17
# L == H
# fullSet, iter: 0 i:578, pairs changed 17
# L == H
# fullSet, iter: 0 i:579, pairs changed 17
# L == H
# fullSet, iter: 0 i:580, pairs changed 17
# L == H
# fullSet, iter: 0 i:581, pairs changed 17
# L == H
# fullSet, iter: 0 i:582, pairs changed 17
# L == H
# fullSet, iter: 0 i:583, pairs changed 17
# L == H
# fullSet, iter: 0 i:584, pairs changed 17
# L == H
# fullSet, iter: 0 i:585, pairs changed 17
# L == H
# fullSet, iter: 0 i:586, pairs changed 17
# L == H
# fullSet, iter: 0 i:587, pairs changed 17
# L == H
# fullSet, iter: 0 i:588, pairs changed 17
# L == H
# fullSet, iter: 0 i:589, pairs changed 17
# L == H
# fullSet, iter: 0 i:590, pairs changed 17
# L == H
# fullSet, iter: 0 i:591, pairs changed 17
# L == H
# fullSet, iter: 0 i:592, pairs changed 17
# L == H
# fullSet, iter: 0 i:593, pairs changed 17
# L == H
# fullSet, iter: 0 i:594, pairs changed 17
# L == H
# fullSet, iter: 0 i:595, pairs changed 17
# L == H
# fullSet, iter: 0 i:596, pairs changed 17
# L == H
# fullSet, iter: 0 i:597, pairs changed 17
# L == H
# fullSet, iter: 0 i:598, pairs changed 17
# L == H
# fullSet, iter: 0 i:599, pairs changed 17
# L == H
# fullSet, iter: 0 i:600, pairs changed 17
# L == H
# fullSet, iter: 0 i:601, pairs changed 17
# L == H
# fullSet, iter: 0 i:602, pairs changed 17
# L == H
# fullSet, iter: 0 i:603, pairs changed 17
# L == H
# fullSet, iter: 0 i:604, pairs changed 17
# L == H
# fullSet, iter: 0 i:605, pairs changed 17
# L == H
# fullSet, iter: 0 i:606, pairs changed 17
# L == H
# fullSet, iter: 0 i:607, pairs changed 17
# L == H
# fullSet, iter: 0 i:608, pairs changed 17
# L == H
# fullSet, iter: 0 i:609, pairs changed 17
# L == H
# fullSet, iter: 0 i:610, pairs changed 17
# L == H
# fullSet, iter: 0 i:611, pairs changed 17
# L == H
# fullSet, iter: 0 i:612, pairs changed 17
# L == H
# fullSet, iter: 0 i:613, pairs changed 17
# L == H
# fullSet, iter: 0 i:614, pairs changed 17
# L == H
# fullSet, iter: 0 i:615, pairs changed 17
# L == H
# fullSet, iter: 0 i:616, pairs changed 17
# L == H
# fullSet, iter: 0 i:617, pairs changed 17
# L == H
# fullSet, iter: 0 i:618, pairs changed 17
# L == H
# fullSet, iter: 0 i:619, pairs changed 17
# L == H
# fullSet, iter: 0 i:620, pairs changed 17
# L == H
# fullSet, iter: 0 i:621, pairs changed 17
# L == H
# fullSet, iter: 0 i:622, pairs changed 17
# L == H
# fullSet, iter: 0 i:623, pairs changed 17
# L == H
# fullSet, iter: 0 i:624, pairs changed 17
# L == H
# fullSet, iter: 0 i:625, pairs changed 17
# L == H
# fullSet, iter: 0 i:626, pairs changed 17
# fullSet, iter: 0 i:627, pairs changed 17
# L == H
# fullSet, iter: 0 i:628, pairs changed 17
# L == H
# fullSet, iter: 0 i:629, pairs changed 17
# L == H
# fullSet, iter: 0 i:630, pairs changed 17
# L == H
# fullSet, iter: 0 i:631, pairs changed 17
# L == H
# fullSet, iter: 0 i:632, pairs changed 17
# L == H
# fullSet, iter: 0 i:633, pairs changed 17
# L == H
# fullSet, iter: 0 i:634, pairs changed 17
# L == H
# fullSet, iter: 0 i:635, pairs changed 17
# L == H
# fullSet, iter: 0 i:636, pairs changed 17
# L == H
# fullSet, iter: 0 i:637, pairs changed 17
# L == H
# fullSet, iter: 0 i:638, pairs changed 17
# L == H
# fullSet, iter: 0 i:639, pairs changed 17
# L == H
# fullSet, iter: 0 i:640, pairs changed 17
# L == H
# fullSet, iter: 0 i:641, pairs changed 17
# L == H
# fullSet, iter: 0 i:642, pairs changed 17
# L == H
# fullSet, iter: 0 i:643, pairs changed 17
# L == H
# fullSet, iter: 0 i:644, pairs changed 17
# fullSet, iter: 0 i:645, pairs changed 17
# L == H
# fullSet, iter: 0 i:646, pairs changed 17
# L == H
# fullSet, iter: 0 i:647, pairs changed 17
# L == H
# fullSet, iter: 0 i:648, pairs changed 17
# L == H
# fullSet, iter: 0 i:649, pairs changed 17
# L == H
# fullSet, iter: 0 i:650, pairs changed 17
# L == H
# fullSet, iter: 0 i:651, pairs changed 17
# L == H
# fullSet, iter: 0 i:652, pairs changed 17
# L == H
# fullSet, iter: 0 i:653, pairs changed 17
# L == H
# fullSet, iter: 0 i:654, pairs changed 17
# L == H
# fullSet, iter: 0 i:655, pairs changed 17
# L == H
# fullSet, iter: 0 i:656, pairs changed 17
# L == H
# fullSet, iter: 0 i:657, pairs changed 17
# L == H
# fullSet, iter: 0 i:658, pairs changed 17
# L == H
# fullSet, iter: 0 i:659, pairs changed 17
# L == H
# fullSet, iter: 0 i:660, pairs changed 17
# L == H
# fullSet, iter: 0 i:661, pairs changed 17
# L == H
# fullSet, iter: 0 i:662, pairs changed 17
# L == H
# fullSet, iter: 0 i:663, pairs changed 17
# L == H
# fullSet, iter: 0 i:664, pairs changed 17
# L == H
# fullSet, iter: 0 i:665, pairs changed 17
# L == H
# fullSet, iter: 0 i:666, pairs changed 17
# L == H
# fullSet, iter: 0 i:667, pairs changed 17
# L == H
# fullSet, iter: 0 i:668, pairs changed 17
# L == H
# fullSet, iter: 0 i:669, pairs changed 17
# L == H
# fullSet, iter: 0 i:670, pairs changed 17
# L == H
# fullSet, iter: 0 i:671, pairs changed 17
# L == H
# fullSet, iter: 0 i:672, pairs changed 17
# L == H
# fullSet, iter: 0 i:673, pairs changed 17
# L == H
# fullSet, iter: 0 i:674, pairs changed 17
# L == H
# fullSet, iter: 0 i:675, pairs changed 17
# L == H
# fullSet, iter: 0 i:676, pairs changed 17
# L == H
# fullSet, iter: 0 i:677, pairs changed 17
# L == H
# fullSet, iter: 0 i:678, pairs changed 17
# L == H
# fullSet, iter: 0 i:679, pairs changed 17
# L == H
# fullSet, iter: 0 i:680, pairs changed 17
# L == H
# fullSet, iter: 0 i:681, pairs changed 17
# L == H
# fullSet, iter: 0 i:682, pairs changed 17
# L == H
# fullSet, iter: 0 i:683, pairs changed 17
# L == H
# fullSet, iter: 0 i:684, pairs changed 17
# L == H
# fullSet, iter: 0 i:685, pairs changed 17
# L == H
# fullSet, iter: 0 i:686, pairs changed 17
# L == H
# fullSet, iter: 0 i:687, pairs changed 17
# L == H
# fullSet, iter: 0 i:688, pairs changed 17
# L == H
# fullSet, iter: 0 i:689, pairs changed 17
# L == H
# fullSet, iter: 0 i:690, pairs changed 17
# L == H
# fullSet, iter: 0 i:691, pairs changed 17
# L == H
# fullSet, iter: 0 i:692, pairs changed 17
# L == H
# fullSet, iter: 0 i:693, pairs changed 17
# L == H
# fullSet, iter: 0 i:694, pairs changed 17
# L == H
# fullSet, iter: 0 i:695, pairs changed 17
# L == H
# fullSet, iter: 0 i:696, pairs changed 17
# L == H
# fullSet, iter: 0 i:697, pairs changed 17
# L == H
# fullSet, iter: 0 i:698, pairs changed 17
# fullSet, iter: 0 i:699, pairs changed 17
# L == H
# fullSet, iter: 0 i:700, pairs changed 17
# L == H
# fullSet, iter: 0 i:701, pairs changed 17
# L == H
# fullSet, iter: 0 i:702, pairs changed 17
# L == H
# fullSet, iter: 0 i:703, pairs changed 17
# L == H
# fullSet, iter: 0 i:704, pairs changed 17
# L == H
# fullSet, iter: 0 i:705, pairs changed 17
# L == H
# fullSet, iter: 0 i:706, pairs changed 17
# L == H
# fullSet, iter: 0 i:707, pairs changed 17
# L == H
# fullSet, iter: 0 i:708, pairs changed 17
# L == H
# fullSet, iter: 0 i:709, pairs changed 17
# L == H
# fullSet, iter: 0 i:710, pairs changed 17
# L == H
# fullSet, iter: 0 i:711, pairs changed 17
# L == H
# fullSet, iter: 0 i:712, pairs changed 17
# L == H
# fullSet, iter: 0 i:713, pairs changed 17
# L == H
# fullSet, iter: 0 i:714, pairs changed 17
# L == H
# fullSet, iter: 0 i:715, pairs changed 17
# L == H
# fullSet, iter: 0 i:716, pairs changed 17
# L == H
# fullSet, iter: 0 i:717, pairs changed 17
# L == H
# fullSet, iter: 0 i:718, pairs changed 17
# L == H
# fullSet, iter: 0 i:719, pairs changed 17
# L == H
# fullSet, iter: 0 i:720, pairs changed 17
# L == H
# fullSet, iter: 0 i:721, pairs changed 17
# L == H
# fullSet, iter: 0 i:722, pairs changed 17
# L == H
# fullSet, iter: 0 i:723, pairs changed 17
# L == H
# fullSet, iter: 0 i:724, pairs changed 17
# fullSet, iter: 0 i:725, pairs changed 17
# L == H
# fullSet, iter: 0 i:726, pairs changed 17
# L == H
# fullSet, iter: 0 i:727, pairs changed 17
# L == H
# fullSet, iter: 0 i:728, pairs changed 17
# L == H
# fullSet, iter: 0 i:729, pairs changed 17
# L == H
# fullSet, iter: 0 i:730, pairs changed 17
# L == H
# fullSet, iter: 0 i:731, pairs changed 17
# L == H
# fullSet, iter: 0 i:732, pairs changed 17
# L == H
# fullSet, iter: 0 i:733, pairs changed 17
# L == H
# fullSet, iter: 0 i:734, pairs changed 17
# L == H
# fullSet, iter: 0 i:735, pairs changed 17
# L == H
# fullSet, iter: 0 i:736, pairs changed 17
# L == H
# fullSet, iter: 0 i:737, pairs changed 17
# L == H
# fullSet, iter: 0 i:738, pairs changed 17
# L == H
# fullSet, iter: 0 i:739, pairs changed 17
# L == H
# fullSet, iter: 0 i:740, pairs changed 17
# L == H
# fullSet, iter: 0 i:741, pairs changed 17
# L == H
# fullSet, iter: 0 i:742, pairs changed 17
# L == H
# fullSet, iter: 0 i:743, pairs changed 17
# L == H
# fullSet, iter: 0 i:744, pairs changed 17
# L == H
# fullSet, iter: 0 i:745, pairs changed 17
# L == H
# fullSet, iter: 0 i:746, pairs changed 17
# fullSet, iter: 0 i:747, pairs changed 17
# L == H
# fullSet, iter: 0 i:748, pairs changed 17
# fullSet, iter: 0 i:749, pairs changed 17
# L == H
# fullSet, iter: 0 i:750, pairs changed 17
# L == H
# fullSet, iter: 0 i:751, pairs changed 17
# fullSet, iter: 0 i:752, pairs changed 17
# fullSet, iter: 0 i:753, pairs changed 17
# fullSet, iter: 0 i:754, pairs changed 17
# fullSet, iter: 0 i:755, pairs changed 17
# fullSet, iter: 0 i:756, pairs changed 17
# fullSet, iter: 0 i:757, pairs changed 17
# fullSet, iter: 0 i:758, pairs changed 17
# fullSet, iter: 0 i:759, pairs changed 17
# fullSet, iter: 0 i:760, pairs changed 17
# fullSet, iter: 0 i:761, pairs changed 17
# fullSet, iter: 0 i:762, pairs changed 17
# fullSet, iter: 0 i:763, pairs changed 17
# fullSet, iter: 0 i:764, pairs changed 17
# fullSet, iter: 0 i:765, pairs changed 17
# fullSet, iter: 0 i:766, pairs changed 17
# fullSet, iter: 0 i:767, pairs changed 17
# fullSet, iter: 0 i:768, pairs changed 17
# fullSet, iter: 0 i:769, pairs changed 17
# fullSet, iter: 0 i:770, pairs changed 17
# fullSet, iter: 0 i:771, pairs changed 17
# fullSet, iter: 0 i:772, pairs changed 17
# fullSet, iter: 0 i:773, pairs changed 17
# fullSet, iter: 0 i:774, pairs changed 17
# fullSet, iter: 0 i:775, pairs changed 17
# fullSet, iter: 0 i:776, pairs changed 17
# fullSet, iter: 0 i:777, pairs changed 17
# fullSet, iter: 0 i:778, pairs changed 17
# fullSet, iter: 0 i:779, pairs changed 17
# fullSet, iter: 0 i:780, pairs changed 17
# L == H
# fullSet, iter: 0 i:781, pairs changed 17
# L == H
# fullSet, iter: 0 i:782, pairs changed 17
# L == H
# fullSet, iter: 0 i:783, pairs changed 17
# L == H
# fullSet, iter: 0 i:784, pairs changed 17
# L == H
# fullSet, iter: 0 i:785, pairs changed 17
# L == H
# fullSet, iter: 0 i:786, pairs changed 17
# L == H
# fullSet, iter: 0 i:787, pairs changed 17
# L == H
# fullSet, iter: 0 i:788, pairs changed 17
# L == H
# fullSet, iter: 0 i:789, pairs changed 17
# L == H
# fullSet, iter: 0 i:790, pairs changed 17
# L == H
# fullSet, iter: 0 i:791, pairs changed 17
# L == H
# fullSet, iter: 0 i:792, pairs changed 17
# L == H
# fullSet, iter: 0 i:793, pairs changed 17
# L == H
# fullSet, iter: 0 i:794, pairs changed 17
# L == H
# fullSet, iter: 0 i:795, pairs changed 17
# L == H
# fullSet, iter: 0 i:796, pairs changed 17
# L == H
# fullSet, iter: 0 i:797, pairs changed 17
# L == H
# fullSet, iter: 0 i:798, pairs changed 17
# L == H
# fullSet, iter: 0 i:799, pairs changed 17
# L == H
# fullSet, iter: 0 i:800, pairs changed 17
# L == H
# fullSet, iter: 0 i:801, pairs changed 17
# L == H
# fullSet, iter: 0 i:802, pairs changed 17
# L == H
# fullSet, iter: 0 i:803, pairs changed 17
# L == H
# fullSet, iter: 0 i:804, pairs changed 17
# L == H
# fullSet, iter: 0 i:805, pairs changed 17
# L == H
# fullSet, iter: 0 i:806, pairs changed 17
# L == H
# fullSet, iter: 0 i:807, pairs changed 17
# L == H
# fullSet, iter: 0 i:808, pairs changed 17
# L == H
# fullSet, iter: 0 i:809, pairs changed 17
# L == H
# fullSet, iter: 0 i:810, pairs changed 17
# fullSet, iter: 0 i:811, pairs changed 17
# L == H
# fullSet, iter: 0 i:812, pairs changed 17
# fullSet, iter: 0 i:813, pairs changed 17
# fullSet, iter: 0 i:814, pairs changed 17
# fullSet, iter: 0 i:815, pairs changed 17
# fullSet, iter: 0 i:816, pairs changed 17
# fullSet, iter: 0 i:817, pairs changed 17
# fullSet, iter: 0 i:818, pairs changed 17
# fullSet, iter: 0 i:819, pairs changed 17
# fullSet, iter: 0 i:820, pairs changed 17
# fullSet, iter: 0 i:821, pairs changed 17
# fullSet, iter: 0 i:822, pairs changed 17
# fullSet, iter: 0 i:823, pairs changed 17
# fullSet, iter: 0 i:824, pairs changed 17
# fullSet, iter: 0 i:825, pairs changed 17
# fullSet, iter: 0 i:826, pairs changed 17
# fullSet, iter: 0 i:827, pairs changed 17
# fullSet, iter: 0 i:828, pairs changed 17
# fullSet, iter: 0 i:829, pairs changed 17
# fullSet, iter: 0 i:830, pairs changed 17
# fullSet, iter: 0 i:831, pairs changed 17
# fullSet, iter: 0 i:832, pairs changed 17
# fullSet, iter: 0 i:833, pairs changed 17
# fullSet, iter: 0 i:834, pairs changed 17
# fullSet, iter: 0 i:835, pairs changed 17
# fullSet, iter: 0 i:836, pairs changed 17
# fullSet, iter: 0 i:837, pairs changed 17
# fullSet, iter: 0 i:838, pairs changed 17
# fullSet, iter: 0 i:839, pairs changed 17
# fullSet, iter: 0 i:840, pairs changed 17
# fullSet, iter: 0 i:841, pairs changed 17
# fullSet, iter: 0 i:842, pairs changed 17
# fullSet, iter: 0 i:843, pairs changed 17
# fullSet, iter: 0 i:844, pairs changed 17
# fullSet, iter: 0 i:845, pairs changed 17
# fullSet, iter: 0 i:846, pairs changed 17
# fullSet, iter: 0 i:847, pairs changed 17
# fullSet, iter: 0 i:848, pairs changed 17
# fullSet, iter: 0 i:849, pairs changed 17
# fullSet, iter: 0 i:850, pairs changed 17
# fullSet, iter: 0 i:851, pairs changed 17
# fullSet, iter: 0 i:852, pairs changed 17
# fullSet, iter: 0 i:853, pairs changed 17
# fullSet, iter: 0 i:854, pairs changed 17
# fullSet, iter: 0 i:855, pairs changed 17
# fullSet, iter: 0 i:856, pairs changed 17
# fullSet, iter: 0 i:857, pairs changed 17
# fullSet, iter: 0 i:858, pairs changed 17
# fullSet, iter: 0 i:859, pairs changed 17
# fullSet, iter: 0 i:860, pairs changed 17
# fullSet, iter: 0 i:861, pairs changed 17
# fullSet, iter: 0 i:862, pairs changed 17
# fullSet, iter: 1 i:0, pairs changed 0
# fullSet, iter: 1 i:1, pairs changed 0
# fullSet, iter: 1 i:2, pairs changed 0
# L == H
# fullSet, iter: 1 i:3, pairs changed 0
# L == H
# fullSet, iter: 1 i:4, pairs changed 0
# L == H
# fullSet, iter: 1 i:5, pairs changed 0
# L == H
# fullSet, iter: 1 i:6, pairs changed 0
# L == H
# fullSet, iter: 1 i:7, pairs changed 0
# L == H
# fullSet, iter: 1 i:8, pairs changed 0
# L == H
# fullSet, iter: 1 i:9, pairs changed 0
# L == H
# fullSet, iter: 1 i:10, pairs changed 0
# L == H
# fullSet, iter: 1 i:11, pairs changed 0
# L == H
# fullSet, iter: 1 i:12, pairs changed 0
# L == H
# fullSet, iter: 1 i:13, pairs changed 0
# L == H
# fullSet, iter: 1 i:14, pairs changed 0
# L == H
# fullSet, iter: 1 i:15, pairs changed 0
# L == H
# fullSet, iter: 1 i:16, pairs changed 0
# L == H
# fullSet, iter: 1 i:17, pairs changed 0
# L == H
# fullSet, iter: 1 i:18, pairs changed 0
# L == H
# fullSet, iter: 1 i:19, pairs changed 0
# L == H
# fullSet, iter: 1 i:20, pairs changed 0
# L == H
# fullSet, iter: 1 i:21, pairs changed 0
# L == H
# fullSet, iter: 1 i:22, pairs changed 0
# L == H
# fullSet, iter: 1 i:23, pairs changed 0
# L == H
# fullSet, iter: 1 i:24, pairs changed 0
# L == H
# fullSet, iter: 1 i:25, pairs changed 0
# L == H
# fullSet, iter: 1 i:26, pairs changed 0
# L == H
# fullSet, iter: 1 i:27, pairs changed 0
# L == H
# fullSet, iter: 1 i:28, pairs changed 0
# L == H
# fullSet, iter: 1 i:29, pairs changed 0
# L == H
# fullSet, iter: 1 i:30, pairs changed 0
# L == H
# fullSet, iter: 1 i:31, pairs changed 0
# L == H
# fullSet, iter: 1 i:32, pairs changed 0
# L == H
# fullSet, iter: 1 i:33, pairs changed 0
# L == H
# fullSet, iter: 1 i:34, pairs changed 0
# L == H
# fullSet, iter: 1 i:35, pairs changed 0
# L == H
# fullSet, iter: 1 i:36, pairs changed 0
# L == H
# fullSet, iter: 1 i:37, pairs changed 0
# L == H
# fullSet, iter: 1 i:38, pairs changed 0
# L == H
# fullSet, iter: 1 i:39, pairs changed 0
# L == H
# fullSet, iter: 1 i:40, pairs changed 0
# L == H
# fullSet, iter: 1 i:41, pairs changed 0
# L == H
# fullSet, iter: 1 i:42, pairs changed 0
# L == H
# fullSet, iter: 1 i:43, pairs changed 0
# L == H
# fullSet, iter: 1 i:44, pairs changed 0
# L == H
# fullSet, iter: 1 i:45, pairs changed 0
# L == H
# fullSet, iter: 1 i:46, pairs changed 0
# L == H
# fullSet, iter: 1 i:47, pairs changed 0
# L == H
# fullSet, iter: 1 i:48, pairs changed 0
# L == H
# fullSet, iter: 1 i:49, pairs changed 0
# L == H
# fullSet, iter: 1 i:50, pairs changed 0
# L == H
# fullSet, iter: 1 i:51, pairs changed 0
# L == H
# fullSet, iter: 1 i:52, pairs changed 0
# L == H
# fullSet, iter: 1 i:53, pairs changed 0
# L == H
# fullSet, iter: 1 i:54, pairs changed 0
# L == H
# fullSet, iter: 1 i:55, pairs changed 0
# L == H
# fullSet, iter: 1 i:56, pairs changed 0
# L == H
# fullSet, iter: 1 i:57, pairs changed 0
# L == H
# fullSet, iter: 1 i:58, pairs changed 0
# L == H
# fullSet, iter: 1 i:59, pairs changed 0
# L == H
# fullSet, iter: 1 i:60, pairs changed 0
# L == H
# fullSet, iter: 1 i:61, pairs changed 0
# L == H
# fullSet, iter: 1 i:62, pairs changed 0
# L == H
# fullSet, iter: 1 i:63, pairs changed 0
# L == H
# fullSet, iter: 1 i:64, pairs changed 0
# L == H
# fullSet, iter: 1 i:65, pairs changed 0
# L == H
# fullSet, iter: 1 i:66, pairs changed 0
# L == H
# fullSet, iter: 1 i:67, pairs changed 0
# L == H
# fullSet, iter: 1 i:68, pairs changed 0
# L == H
# fullSet, iter: 1 i:69, pairs changed 0
# L == H
# fullSet, iter: 1 i:70, pairs changed 0
# L == H
# fullSet, iter: 1 i:71, pairs changed 0
# L == H
# fullSet, iter: 1 i:72, pairs changed 0
# L == H
# fullSet, iter: 1 i:73, pairs changed 0
# L == H
# fullSet, iter: 1 i:74, pairs changed 0
# L == H
# fullSet, iter: 1 i:75, pairs changed 0
# L == H
# fullSet, iter: 1 i:76, pairs changed 0
# L == H
# fullSet, iter: 1 i:77, pairs changed 0
# L == H
# fullSet, iter: 1 i:78, pairs changed 0
# L == H
# fullSet, iter: 1 i:79, pairs changed 0
# L == H
# fullSet, iter: 1 i:80, pairs changed 0
# L == H
# fullSet, iter: 1 i:81, pairs changed 0
# L == H
# fullSet, iter: 1 i:82, pairs changed 0
# L == H
# fullSet, iter: 1 i:83, pairs changed 0
# L == H
# fullSet, iter: 1 i:84, pairs changed 0
# L == H
# fullSet, iter: 1 i:85, pairs changed 0
# L == H
# fullSet, iter: 1 i:86, pairs changed 0
# L == H
# fullSet, iter: 1 i:87, pairs changed 0
# L == H
# fullSet, iter: 1 i:88, pairs changed 0
# L == H
# fullSet, iter: 1 i:89, pairs changed 0
# L == H
# fullSet, iter: 1 i:90, pairs changed 0
# L == H
# fullSet, iter: 1 i:91, pairs changed 0
# L == H
# fullSet, iter: 1 i:92, pairs changed 0
# L == H
# fullSet, iter: 1 i:93, pairs changed 0
# L == H
# fullSet, iter: 1 i:94, pairs changed 0
# L == H
# fullSet, iter: 1 i:95, pairs changed 0
# L == H
# fullSet, iter: 1 i:96, pairs changed 0
# L == H
# fullSet, iter: 1 i:97, pairs changed 0
# L == H
# fullSet, iter: 1 i:98, pairs changed 0
# L == H
# fullSet, iter: 1 i:99, pairs changed 0
# L == H
# fullSet, iter: 1 i:100, pairs changed 0
# L == H
# fullSet, iter: 1 i:101, pairs changed 0
# L == H
# fullSet, iter: 1 i:102, pairs changed 0
# L == H
# fullSet, iter: 1 i:103, pairs changed 0
# L == H
# fullSet, iter: 1 i:104, pairs changed 0
# L == H
# fullSet, iter: 1 i:105, pairs changed 0
# L == H
# fullSet, iter: 1 i:106, pairs changed 0
# L == H
# fullSet, iter: 1 i:107, pairs changed 0
# L == H
# fullSet, iter: 1 i:108, pairs changed 0
# L == H
# fullSet, iter: 1 i:109, pairs changed 0
# L == H
# fullSet, iter: 1 i:110, pairs changed 0
# L == H
# fullSet, iter: 1 i:111, pairs changed 0
# L == H
# fullSet, iter: 1 i:112, pairs changed 0
# L == H
# fullSet, iter: 1 i:113, pairs changed 0
# L == H
# fullSet, iter: 1 i:114, pairs changed 0
# L == H
# fullSet, iter: 1 i:115, pairs changed 0
# L == H
# fullSet, iter: 1 i:116, pairs changed 0
# L == H
# fullSet, iter: 1 i:117, pairs changed 0
# L == H
# fullSet, iter: 1 i:118, pairs changed 0
# L == H
# fullSet, iter: 1 i:119, pairs changed 0
# L == H
# fullSet, iter: 1 i:120, pairs changed 0
# L == H
# fullSet, iter: 1 i:121, pairs changed 0
# L == H
# fullSet, iter: 1 i:122, pairs changed 0
# L == H
# fullSet, iter: 1 i:123, pairs changed 0
# L == H
# fullSet, iter: 1 i:124, pairs changed 0
# L == H
# fullSet, iter: 1 i:125, pairs changed 0
# L == H
# fullSet, iter: 1 i:126, pairs changed 0
# L == H
# fullSet, iter: 1 i:127, pairs changed 0
# L == H
# fullSet, iter: 1 i:128, pairs changed 0
# L == H
# fullSet, iter: 1 i:129, pairs changed 0
# L == H
# fullSet, iter: 1 i:130, pairs changed 0
# L == H
# fullSet, iter: 1 i:131, pairs changed 0
# L == H
# fullSet, iter: 1 i:132, pairs changed 0
# L == H
# fullSet, iter: 1 i:133, pairs changed 0
# L == H
# fullSet, iter: 1 i:134, pairs changed 0
# L == H
# fullSet, iter: 1 i:135, pairs changed 0
# L == H
# fullSet, iter: 1 i:136, pairs changed 0
# L == H
# fullSet, iter: 1 i:137, pairs changed 0
# L == H
# fullSet, iter: 1 i:138, pairs changed 0
# L == H
# fullSet, iter: 1 i:139, pairs changed 0
# L == H
# fullSet, iter: 1 i:140, pairs changed 0
# L == H
# fullSet, iter: 1 i:141, pairs changed 0
# L == H
# fullSet, iter: 1 i:142, pairs changed 0
# L == H
# fullSet, iter: 1 i:143, pairs changed 0
# L == H
# fullSet, iter: 1 i:144, pairs changed 0
# L == H
# fullSet, iter: 1 i:145, pairs changed 0
# L == H
# fullSet, iter: 1 i:146, pairs changed 0
# L == H
# fullSet, iter: 1 i:147, pairs changed 0
# L == H
# fullSet, iter: 1 i:148, pairs changed 0
# L == H
# fullSet, iter: 1 i:149, pairs changed 0
# L == H
# fullSet, iter: 1 i:150, pairs changed 0
# L == H
# fullSet, iter: 1 i:151, pairs changed 0
# L == H
# fullSet, iter: 1 i:152, pairs changed 0
# L == H
# fullSet, iter: 1 i:153, pairs changed 0
# L == H
# fullSet, iter: 1 i:154, pairs changed 0
# L == H
# fullSet, iter: 1 i:155, pairs changed 0
# L == H
# fullSet, iter: 1 i:156, pairs changed 0
# L == H
# fullSet, iter: 1 i:157, pairs changed 0
# L == H
# fullSet, iter: 1 i:158, pairs changed 0
# L == H
# fullSet, iter: 1 i:159, pairs changed 0
# L == H
# fullSet, iter: 1 i:160, pairs changed 0
# L == H
# fullSet, iter: 1 i:161, pairs changed 0
# L == H
# fullSet, iter: 1 i:162, pairs changed 0
# L == H
# fullSet, iter: 1 i:163, pairs changed 0
# L == H
# fullSet, iter: 1 i:164, pairs changed 0
# L == H
# fullSet, iter: 1 i:165, pairs changed 0
# L == H
# fullSet, iter: 1 i:166, pairs changed 0
# L == H
# fullSet, iter: 1 i:167, pairs changed 0
# L == H
# fullSet, iter: 1 i:168, pairs changed 0
# L == H
# fullSet, iter: 1 i:169, pairs changed 0
# L == H
# fullSet, iter: 1 i:170, pairs changed 0
# L == H
# ...
# L == H
# fullSet, iter: 1 i:511, pairs changed 0
# L == H
# fullSet, iter: 1 i:512, pairs changed 0
# L == H
# fullSet, iter: 1 i:513, pairs changed 0
# L == H
# fullSet, iter: 1 i:514, pairs changed 0
# L == H
# fullSet, iter: 1 i:515, pairs changed 0
# L == H
# fullSet, iter: 1 i:516, pairs changed 0
# L == H
# fullSet, iter: 1 i:517, pairs changed 0
# L == H
# fullSet, iter: 1 i:518, pairs changed 0
# L == H
# fullSet, iter: 1 i:519, pairs changed 0
# fullSet, iter: 1 i:520, pairs changed 0
# L == H
# fullSet, iter: 1 i:521, pairs changed 0
# L == H
# fullSet, iter: 1 i:522, pairs changed 0
# L == H
# fullSet, iter: 1 i:523, pairs changed 0
# L == H
# fullSet, iter: 1 i:524, pairs changed 0
# L == H
# fullSet, iter: 1 i:525, pairs changed 0
# L == H
# fullSet, iter: 1 i:526, pairs changed 0
# L == H
# fullSet, iter: 1 i:527, pairs changed 0
# L == H
# fullSet, iter: 1 i:528, pairs changed 0
# L == H
# fullSet, iter: 1 i:529, pairs changed 0
# L == H
# fullSet, iter: 1 i:530, pairs changed 0
# L == H
# fullSet, iter: 1 i:531, pairs changed 0
# L == H
# fullSet, iter: 1 i:532, pairs changed 0
# L == H
# fullSet, iter: 1 i:533, pairs changed 0
# L == H
# fullSet, iter: 1 i:534, pairs changed 0
# L == H
# fullSet, iter: 1 i:535, pairs changed 0
# L == H
# fullSet, iter: 1 i:536, pairs changed 0
# L == H
# fullSet, iter: 1 i:537, pairs changed 0
# fullSet, iter: 1 i:538, pairs changed 0
# L == H
# fullSet, iter: 1 i:539, pairs changed 0
# L == H
# fullSet, iter: 1 i:540, pairs changed 0
# L == H
# fullSet, iter: 1 i:541, pairs changed 0
# L == H
# fullSet, iter: 1 i:542, pairs changed 0
# L == H
# fullSet, iter: 1 i:543, pairs changed 0
# L == H
# fullSet, iter: 1 i:544, pairs changed 0
# L == H
# fullSet, iter: 1 i:545, pairs changed 0
# L == H
# fullSet, iter: 1 i:546, pairs changed 0
# L == H
# fullSet, iter: 1 i:547, pairs changed 0
# L == H
# fullSet, iter: 1 i:548, pairs changed 0
# L == H
# fullSet, iter: 1 i:549, pairs changed 0
# L == H
# fullSet, iter: 1 i:550, pairs changed 0
# L == H
# fullSet, iter: 1 i:551, pairs changed 0
# L == H
# fullSet, iter: 1 i:552, pairs changed 0
# L == H
# fullSet, iter: 1 i:553, pairs changed 0
# L == H
# fullSet, iter: 1 i:554, pairs changed 0
# L == H
# fullSet, iter: 1 i:555, pairs changed 0
# L == H
# fullSet, iter: 1 i:556, pairs changed 0
# L == H
# fullSet, iter: 1 i:557, pairs changed 0
# L == H
# fullSet, iter: 1 i:558, pairs changed 0
# L == H
# fullSet, iter: 1 i:559, pairs changed 0
# L == H
# fullSet, iter: 1 i:560, pairs changed 0
# L == H
# fullSet, iter: 1 i:561, pairs changed 0
# L == H
# fullSet, iter: 1 i:562, pairs changed 0
# fullSet, iter: 1 i:563, pairs changed 0
# L == H
# fullSet, iter: 1 i:564, pairs changed 0
# L == H
# fullSet, iter: 1 i:565, pairs changed 0
# L == H
# fullSet, iter: 1 i:566, pairs changed 0
# L == H
# fullSet, iter: 1 i:567, pairs changed 0
# L == H
# fullSet, iter: 1 i:568, pairs changed 0
# L == H
# fullSet, iter: 1 i:569, pairs changed 0
# L == H
# fullSet, iter: 1 i:570, pairs changed 0
# L == H
# fullSet, iter: 1 i:571, pairs changed 0
# L == H
# fullSet, iter: 1 i:572, pairs changed 0
# fullSet, iter: 1 i:573, pairs changed 0
# fullSet, iter: 1 i:574, pairs changed 0
# fullSet, iter: 1 i:575, pairs changed 0
# L == H
# fullSet, iter: 1 i:576, pairs changed 0
# L == H
# fullSet, iter: 1 i:577, pairs changed 0
# L == H
# fullSet, iter: 1 i:578, pairs changed 0
# L == H
# fullSet, iter: 1 i:579, pairs changed 0
# L == H
# fullSet, iter: 1 i:580, pairs changed 0
# L == H
# fullSet, iter: 1 i:581, pairs changed 0
# L == H
# fullSet, iter: 1 i:582, pairs changed 0
# L == H
# fullSet, iter: 1 i:583, pairs changed 0
# L == H
# fullSet, iter: 1 i:584, pairs changed 0
# L == H
# fullSet, iter: 1 i:585, pairs changed 0
# L == H
# fullSet, iter: 1 i:586, pairs changed 0
# L == H
# fullSet, iter: 1 i:587, pairs changed 0
# L == H
# fullSet, iter: 1 i:588, pairs changed 0
# L == H
# fullSet, iter: 1 i:589, pairs changed 0
# L == H
# fullSet, iter: 1 i:590, pairs changed 0
# L == H
# fullSet, iter: 1 i:591, pairs changed 0
# L == H
# fullSet, iter: 1 i:592, pairs changed 0
# L == H
# fullSet, iter: 1 i:593, pairs changed 0
# L == H
# fullSet, iter: 1 i:594, pairs changed 0
# L == H
# fullSet, iter: 1 i:595, pairs changed 0
# L == H
# fullSet, iter: 1 i:596, pairs changed 0
# L == H
# fullSet, iter: 1 i:597, pairs changed 0
# L == H
# fullSet, iter: 1 i:598, pairs changed 0
# L == H
# fullSet, iter: 1 i:599, pairs changed 0
# L == H
# fullSet, iter: 1 i:600, pairs changed 0
# L == H
# fullSet, iter: 1 i:601, pairs changed 0
# L == H
# fullSet, iter: 1 i:602, pairs changed 0
# L == H
# fullSet, iter: 1 i:603, pairs changed 0
# L == H
# fullSet, iter: 1 i:604, pairs changed 0
# L == H
# fullSet, iter: 1 i:605, pairs changed 0
# L == H
# fullSet, iter: 1 i:606, pairs changed 0
# L == H
# fullSet, iter: 1 i:607, pairs changed 0
# L == H
# fullSet, iter: 1 i:608, pairs changed 0
# L == H
# fullSet, iter: 1 i:609, pairs changed 0
# L == H
# fullSet, iter: 1 i:610, pairs changed 0
# L == H
# fullSet, iter: 1 i:611, pairs changed 0
# L == H
# fullSet, iter: 1 i:612, pairs changed 0
# L == H
# fullSet, iter: 1 i:613, pairs changed 0
# L == H
# fullSet, iter: 1 i:614, pairs changed 0
# L == H
# fullSet, iter: 1 i:615, pairs changed 0
# L == H
# fullSet, iter: 1 i:616, pairs changed 0
# L == H
# fullSet, iter: 1 i:617, pairs changed 0
# L == H
# fullSet, iter: 1 i:618, pairs changed 0
# L == H
# fullSet, iter: 1 i:619, pairs changed 0
# L == H
# fullSet, iter: 1 i:620, pairs changed 0
# L == H
# fullSet, iter: 1 i:621, pairs changed 0
# L == H
# fullSet, iter: 1 i:622, pairs changed 0
# L == H
# fullSet, iter: 1 i:623, pairs changed 0
# L == H
# fullSet, iter: 1 i:624, pairs changed 0
# L == H
# fullSet, iter: 1 i:625, pairs changed 0
# L == H
# fullSet, iter: 1 i:626, pairs changed 0
# fullSet, iter: 1 i:627, pairs changed 0
# L == H
# fullSet, iter: 1 i:628, pairs changed 0
# L == H
# fullSet, iter: 1 i:629, pairs changed 0
# L == H
# fullSet, iter: 1 i:630, pairs changed 0
# L == H
# fullSet, iter: 1 i:631, pairs changed 0
# L == H
# fullSet, iter: 1 i:632, pairs changed 0
# L == H
# fullSet, iter: 1 i:633, pairs changed 0
# L == H
# fullSet, iter: 1 i:634, pairs changed 0
# L == H
# fullSet, iter: 1 i:635, pairs changed 0
# L == H
# fullSet, iter: 1 i:636, pairs changed 0
# L == H
# fullSet, iter: 1 i:637, pairs changed 0
# L == H
# fullSet, iter: 1 i:638, pairs changed 0
# L == H
# fullSet, iter: 1 i:639, pairs changed 0
# L == H
# fullSet, iter: 1 i:640, pairs changed 0
# L == H
# fullSet, iter: 1 i:641, pairs changed 0
# L == H
# fullSet, iter: 1 i:642, pairs changed 0
# L == H
# fullSet, iter: 1 i:643, pairs changed 0
# L == H
# fullSet, iter: 1 i:644, pairs changed 0
# fullSet, iter: 1 i:645, pairs changed 0
# L == H
# fullSet, iter: 1 i:646, pairs changed 0
# L == H
# fullSet, iter: 1 i:647, pairs changed 0
# L == H
# fullSet, iter: 1 i:648, pairs changed 0
# L == H
# fullSet, iter: 1 i:649, pairs changed 0
# L == H
# fullSet, iter: 1 i:650, pairs changed 0
# L == H
# fullSet, iter: 1 i:651, pairs changed 0
# L == H
# fullSet, iter: 1 i:652, pairs changed 0
# L == H
# fullSet, iter: 1 i:653, pairs changed 0
# L == H
# fullSet, iter: 1 i:654, pairs changed 0
# L == H
# fullSet, iter: 1 i:655, pairs changed 0
# L == H
# fullSet, iter: 1 i:656, pairs changed 0
# L == H
# fullSet, iter: 1 i:657, pairs changed 0
# L == H
# fullSet, iter: 1 i:658, pairs changed 0
# L == H
# fullSet, iter: 1 i:659, pairs changed 0
# L == H
# fullSet, iter: 1 i:660, pairs changed 0
# L == H
# fullSet, iter: 1 i:661, pairs changed 0
# L == H
# fullSet, iter: 1 i:662, pairs changed 0
# L == H
# fullSet, iter: 1 i:663, pairs changed 0
# L == H
# fullSet, iter: 1 i:664, pairs changed 0
# L == H
# fullSet, iter: 1 i:665, pairs changed 0
# L == H
# fullSet, iter: 1 i:666, pairs changed 0
# L == H
# fullSet, iter: 1 i:667, pairs changed 0
# L == H
# fullSet, iter: 1 i:668, pairs changed 0
# L == H
# fullSet, iter: 1 i:669, pairs changed 0
# L == H
# fullSet, iter: 1 i:670, pairs changed 0
# L == H
# fullSet, iter: 1 i:671, pairs changed 0
# L == H
# fullSet, iter: 1 i:672, pairs changed 0
# L == H
# fullSet, iter: 1 i:673, pairs changed 0
# L == H
# fullSet, iter: 1 i:674, pairs changed 0
# L == H
# fullSet, iter: 1 i:675, pairs changed 0
# L == H
# fullSet, iter: 1 i:676, pairs changed 0
# L == H
# fullSet, iter: 1 i:677, pairs changed 0
# L == H
# fullSet, iter: 1 i:678, pairs changed 0
# L == H
# fullSet, iter: 1 i:679, pairs changed 0
# L == H
# fullSet, iter: 1 i:680, pairs changed 0
# L == H
# fullSet, iter: 1 i:681, pairs changed 0
# L == H
# fullSet, iter: 1 i:682, pairs changed 0
# L == H
# fullSet, iter: 1 i:683, pairs changed 0
# L == H
# fullSet, iter: 1 i:684, pairs changed 0
# L == H
# fullSet, iter: 1 i:685, pairs changed 0
# L == H
# fullSet, iter: 1 i:686, pairs changed 0
# L == H
# fullSet, iter: 1 i:687, pairs changed 0
# L == H
# fullSet, iter: 1 i:688, pairs changed 0
# L == H
# fullSet, iter: 1 i:689, pairs changed 0
# L == H
# fullSet, iter: 1 i:690, pairs changed 0
# L == H
# fullSet, iter: 1 i:691, pairs changed 0
# L == H
# fullSet, iter: 1 i:692, pairs changed 0
# L == H
# fullSet, iter: 1 i:693, pairs changed 0
# L == H
# fullSet, iter: 1 i:694, pairs changed 0
# L == H
# fullSet, iter: 1 i:695, pairs changed 0
# L == H
# fullSet, iter: 1 i:696, pairs changed 0
# L == H
# fullSet, iter: 1 i:697, pairs changed 0
# L == H
# fullSet, iter: 1 i:698, pairs changed 0
# fullSet, iter: 1 i:699, pairs changed 0
# L == H
# fullSet, iter: 1 i:700, pairs changed 0
# L == H
# fullSet, iter: 1 i:701, pairs changed 0
# L == H
# fullSet, iter: 1 i:702, pairs changed 0
# L == H
# fullSet, iter: 1 i:703, pairs changed 0
# L == H
# fullSet, iter: 1 i:704, pairs changed 0
# L == H
# fullSet, iter: 1 i:705, pairs changed 0
# L == H
# fullSet, iter: 1 i:706, pairs changed 0
# L == H
# fullSet, iter: 1 i:707, pairs changed 0
# L == H
# fullSet, iter: 1 i:708, pairs changed 0
# L == H
# fullSet, iter: 1 i:709, pairs changed 0
# L == H
# fullSet, iter: 1 i:710, pairs changed 0
# L == H
# fullSet, iter: 1 i:711, pairs changed 0
# L == H
# fullSet, iter: 1 i:712, pairs changed 0
# L == H
# fullSet, iter: 1 i:713, pairs changed 0
# L == H
# fullSet, iter: 1 i:714, pairs changed 0
# L == H
# fullSet, iter: 1 i:715, pairs changed 0
# L == H
# fullSet, iter: 1 i:716, pairs changed 0
# L == H
# fullSet, iter: 1 i:717, pairs changed 0
# L == H
# fullSet, iter: 1 i:718, pairs changed 0
# L == H
# fullSet, iter: 1 i:719, pairs changed 0
# L == H
# fullSet, iter: 1 i:720, pairs changed 0
# L == H
# fullSet, iter: 1 i:721, pairs changed 0
# L == H
# fullSet, iter: 1 i:722, pairs changed 0
# L == H
# fullSet, iter: 1 i:723, pairs changed 0
# L == H
# fullSet, iter: 1 i:724, pairs changed 0
# fullSet, iter: 1 i:725, pairs changed 0
# L == H
# fullSet, iter: 1 i:726, pairs changed 0
# L == H
# fullSet, iter: 1 i:727, pairs changed 0
# L == H
# fullSet, iter: 1 i:728, pairs changed 0
# L == H
# fullSet, iter: 1 i:729, pairs changed 0
# L == H
# fullSet, iter: 1 i:730, pairs changed 0
# L == H
# fullSet, iter: 1 i:731, pairs changed 0
# L == H
# fullSet, iter: 1 i:732, pairs changed 0
# L == H
# fullSet, iter: 1 i:733, pairs changed 0
# L == H
# fullSet, iter: 1 i:734, pairs changed 0
# L == H
# fullSet, iter: 1 i:735, pairs changed 0
# L == H
# fullSet, iter: 1 i:736, pairs changed 0
# L == H
# fullSet, iter: 1 i:737, pairs changed 0
# L == H
# fullSet, iter: 1 i:738, pairs changed 0
# L == H
# fullSet, iter: 1 i:739, pairs changed 0
# L == H
# fullSet, iter: 1 i:740, pairs changed 0
# L == H
# fullSet, iter: 1 i:741, pairs changed 0
# L == H
# fullSet, iter: 1 i:742, pairs changed 0
# L == H
# fullSet, iter: 1 i:743, pairs changed 0
# L == H
# fullSet, iter: 1 i:744, pairs changed 0
# L == H
# fullSet, iter: 1 i:745, pairs changed 0
# L == H
# fullSet, iter: 1 i:746, pairs changed 0
# fullSet, iter: 1 i:747, pairs changed 0
# L == H
# fullSet, iter: 1 i:748, pairs changed 0
# fullSet, iter: 1 i:749, pairs changed 0
# L == H
# fullSet, iter: 1 i:750, pairs changed 0
# L == H
# fullSet, iter: 1 i:751, pairs changed 0
# fullSet, iter: 1 i:752, pairs changed 0
# fullSet, iter: 1 i:753, pairs changed 0
# fullSet, iter: 1 i:754, pairs changed 0
# fullSet, iter: 1 i:755, pairs changed 0
# fullSet, iter: 1 i:756, pairs changed 0
# fullSet, iter: 1 i:757, pairs changed 0
# fullSet, iter: 1 i:758, pairs changed 0
# fullSet, iter: 1 i:759, pairs changed 0
# fullSet, iter: 1 i:760, pairs changed 0
# fullSet, iter: 1 i:761, pairs changed 0
# fullSet, iter: 1 i:762, pairs changed 0
# fullSet, iter: 1 i:763, pairs changed 0
# fullSet, iter: 1 i:764, pairs changed 0
# fullSet, iter: 1 i:765, pairs changed 0
# fullSet, iter: 1 i:766, pairs changed 0
# fullSet, iter: 1 i:767, pairs changed 0
# fullSet, iter: 1 i:768, pairs changed 0
# fullSet, iter: 1 i:769, pairs changed 0
# fullSet, iter: 1 i:770, pairs changed 0
# fullSet, iter: 1 i:771, pairs changed 0
# fullSet, iter: 1 i:772, pairs changed 0
# fullSet, iter: 1 i:773, pairs changed 0
# fullSet, iter: 1 i:774, pairs changed 0
# fullSet, iter: 1 i:775, pairs changed 0
# fullSet, iter: 1 i:776, pairs changed 0
# fullSet, iter: 1 i:777, pairs changed 0
# fullSet, iter: 1 i:778, pairs changed 0
# fullSet, iter: 1 i:779, pairs changed 0
# fullSet, iter: 1 i:780, pairs changed 0
# L == H
# fullSet, iter: 1 i:781, pairs changed 0
# L == H
# fullSet, iter: 1 i:782, pairs changed 0
# L == H
# fullSet, iter: 1 i:783, pairs changed 0
# L == H
# fullSet, iter: 1 i:784, pairs changed 0
# L == H
# fullSet, iter: 1 i:785, pairs changed 0
# L == H
# fullSet, iter: 1 i:786, pairs changed 0
# L == H
# fullSet, iter: 1 i:787, pairs changed 0
# L == H
# fullSet, iter: 1 i:788, pairs changed 0
# L == H
# fullSet, iter: 1 i:789, pairs changed 0
# L == H
# fullSet, iter: 1 i:790, pairs changed 0
# L == H
# fullSet, iter: 1 i:791, pairs changed 0
# L == H
# fullSet, iter: 1 i:792, pairs changed 0
# L == H
# fullSet, iter: 1 i:793, pairs changed 0
# L == H
# fullSet, iter: 1 i:794, pairs changed 0
# L == H
# fullSet, iter: 1 i:795, pairs changed 0
# L == H
# fullSet, iter: 1 i:796, pairs changed 0
# L == H
# fullSet, iter: 1 i:797, pairs changed 0
# L == H
# fullSet, iter: 1 i:798, pairs changed 0
# L == H
# fullSet, iter: 1 i:799, pairs changed 0
# L == H
# fullSet, iter: 1 i:800, pairs changed 0
# L == H
# fullSet, iter: 1 i:801, pairs changed 0
# L == H
# fullSet, iter: 1 i:802, pairs changed 0
# L == H
# fullSet, iter: 1 i:803, pairs changed 0
# L == H
# fullSet, iter: 1 i:804, pairs changed 0
# L == H
# fullSet, iter: 1 i:805, pairs changed 0
# L == H
# fullSet, iter: 1 i:806, pairs changed 0
# L == H
# fullSet, iter: 1 i:807, pairs changed 0
# L == H
# fullSet, iter: 1 i:808, pairs changed 0
# L == H
# fullSet, iter: 1 i:809, pairs changed 0
# L == H
# fullSet, iter: 1 i:810, pairs changed 0
# fullSet, iter: 1 i:811, pairs changed 0
# L == H
# fullSet, iter: 1 i:812, pairs changed 0
# fullSet, iter: 1 i:813, pairs changed 0
# fullSet, iter: 1 i:814, pairs changed 0
# fullSet, iter: 1 i:815, pairs changed 0
# fullSet, iter: 1 i:816, pairs changed 0
# fullSet, iter: 1 i:817, pairs changed 0
# fullSet, iter: 1 i:818, pairs changed 0
# fullSet, iter: 1 i:819, pairs changed 0
# fullSet, iter: 1 i:820, pairs changed 0
# fullSet, iter: 1 i:821, pairs changed 0
# fullSet, iter: 1 i:822, pairs changed 0
# fullSet, iter: 1 i:823, pairs changed 0
# fullSet, iter: 1 i:824, pairs changed 0
# fullSet, iter: 1 i:825, pairs changed 0
# fullSet, iter: 1 i:826, pairs changed 0
# fullSet, iter: 1 i:827, pairs changed 0
# fullSet, iter: 1 i:828, pairs changed 0
# fullSet, iter: 1 i:829, pairs changed 0
# fullSet, iter: 1 i:830, pairs changed 0
# fullSet, iter: 1 i:831, pairs changed 0
# fullSet, iter: 1 i:832, pairs changed 0
# fullSet, iter: 1 i:833, pairs changed 0
# fullSet, iter: 1 i:834, pairs changed 0
# fullSet, iter: 1 i:835, pairs changed 0
# fullSet, iter: 1 i:836, pairs changed 0
# fullSet, iter: 1 i:837, pairs changed 0
# fullSet, iter: 1 i:838, pairs changed 0
# fullSet, iter: 1 i:839, pairs changed 0
# fullSet, iter: 1 i:840, pairs changed 0
# fullSet, iter: 1 i:841, pairs changed 0
# fullSet, iter: 1 i:842, pairs changed 0
# fullSet, iter: 1 i:843, pairs changed 0
# fullSet, iter: 1 i:844, pairs changed 0
# fullSet, iter: 1 i:845, pairs changed 0
# fullSet, iter: 1 i:846, pairs changed 0
# fullSet, iter: 1 i:847, pairs changed 0
# fullSet, iter: 1 i:848, pairs changed 0
# fullSet, iter: 1 i:849, pairs changed 0
# fullSet, iter: 1 i:850, pairs changed 0
# fullSet, iter: 1 i:851, pairs changed 0
# fullSet, iter: 1 i:852, pairs changed 0
# fullSet, iter: 1 i:853, pairs changed 0
# fullSet, iter: 1 i:854, pairs changed 0
# fullSet, iter: 1 i:855, pairs changed 0
# fullSet, iter: 1 i:856, pairs changed 0
# fullSet, iter: 1 i:857, pairs changed 0
# fullSet, iter: 1 i:858, pairs changed 0
# fullSet, iter: 1 i:859, pairs changed 0
# fullSet, iter: 1 i:860, pairs changed 0
# fullSet, iter: 1 i:861, pairs changed 0
# fullSet, iter: 1 i:862, pairs changed 0
# there are 34 Support Vectors
# the training error rate is: 0.499421
# the test error rate is: 0.672986
